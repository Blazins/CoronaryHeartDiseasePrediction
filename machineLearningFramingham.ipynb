# %% [markdown]
# # Predict 10 Years Risk of Coronary Heart Disease

# %% [markdown]
# You will use logistic regression method to predict if the patient has 10-year risk of future coronary heart disease (CHD) based on medical condition and behavioral risk factors.

# %% [markdown]
# ## Table of Contents
# - [Framingham Data](#Framingham_Data)
# - [Load Libraries](#load_libraries)
# - [Access data](#access_data)
# - [Explore Data](#Explore)
# - [Parse Data](#Parse)
# - [Split Data into Training and Test set](#training_test)
# - [Build Logistic Regression Model](#build_model)
# - [Predict for Test data](#test_data)
# - [Evaluate the Model](#evaluate_model)
# - [ROC curve plot](#ROC_plot)

# %% [markdown]
# <a id="Framingham_Data"></a>
# ## Framingham Data
# You will analyze the random sample of the Coronary Heart Disease data. The Dataset Source: [https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset](https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset)

# %% [markdown]
#  <table style="font-size: 12px; text-align: left;" width=100%>
#   <tr>
#   <td width=5% style="text-align: center; font-size: 12px">
#    </td>
#    <td width=11% style="text-align: left; font-size: 12px">
#    <b>Variable</b>
#    </td>
#    <td width=53% style="text-align: left; font-size: 12px">
#    <b> Description</b>
#    </td>
#     <td width=31% rowspan=17>
#
#    <img src='https://finetreatment.com/wp-content/uploads/2015/03/heart-1.jpg'></img>
#
#   </td>
#   </tr>
#   <tr>
#    <td width=5% style="text-align: center; font-size: 12px">
#      0
#    </td>
#    <td width=11% style="text-align: left; font-size: 12px">
#      PatientID
#    </td>
#    <td width=53% style="text-align: left; font-size: 12px">
#      Patient ID.
#    </td>
#
#  </tr>
#  <tr>
#    <td style="text-align: center; font-size: 12px">
#     1
#   </td>
#   <td style="text-align: left; font-size: 12px">
#    Male
#   </td>
#   <td style="text-align: left; font-size: 12px">
#    0 = Female; 1 = Male
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    2
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   Age
#   </td>
#   <td  style="text-align: left; font-size: 12px">
#   Age at exam time
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#   3
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   Education
#   </td>
#   <td style="text-align: left; font-size: 12px">
#  1 = Some High School; 2 = High School or GED; 3 = Some College or Vocational School; 4 = college
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#   4
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   currentSmoker
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   0 = nonsmoker; 1 = smoker
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    5
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   cigsPerDay
#   </td>
#   <td style="text-align: left; font-size: 12px">
#  estimated average number of cigarettes smoked per day
#   </td>
#  </tr>
#   <tr>
#   <td style="text-align: center; font-size: 12px">
#    6
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   BPMeds
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   0 = Not on Blood Pressure medications; 1 = Is on Blood Pressure medications
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    7
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   prevalentStroke
#   </td>
#   <td style="text-align: left; font-size: 12px">
# whether or not the patient had previously had a stroke; 0 = No; 1 = Yes
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    8
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   prevalentHyp
#   </td>
#   <td style="text-align: left; font-size: 12px">
#  whether or not the patient was hypertensive; 0 = No; 1 = Yes
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    9
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   diabetes
#   </td>
#   <td style="text-align: left; font-size: 12px">
#  whether or not the patient had diabetes; 0 = No; 1 = Yes
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    10
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   totChol
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   total cholesterol level
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 12px">
#    11
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   sysBP
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   systolic blood pressure
#   </td>
#  </tr>
#   <tr>
#   <td style="text-align: center; font-size: 12px">
#    12
#   </td>
#   <td style="text-align: left; font-size: 12px">
#  diaBP
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   diastolic blood pressure
#   </td>
#  </tr>
#   <tr>
#   <td style="text-align: center; font-size: 12px">
#    13
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   BMI
#   </td>
#   <td style="text-align: left; font-size: 12px">
#  Body Mass Index calculated as: Weight (kg) / Height(meter-squared)
#   </td>
#  </tr>
#   <tr>
#   <td style="text-align: center; font-size: 12px">
#    14
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   heartRate
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   Beats/Min (Ventricular)
#   </td>
#  </tr>
#   <tr>
#   <td style="text-align: center; font-size: 12px">
#    15
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   glucose
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   glucose level
#   </td>
#  </tr>
#   <tr>
#   <td style="text-align: center; font-size: 12px">
#    16
#   </td>
#   <td style="text-align: left; font-size: 12px">
#   TenYearCHD
#   </td>
#   <td style="text-align: left; font-size: 12px" colspan=2>
#   10 year risk of coronary heart disease CHD (binary: 1 means Yes, 0 means No)
#   </td>
#  </tr>
# </table>

# %% [markdown]
# <a id="load_libraries"></a>
# ## Load Libraries
#
# The Spark and Python libraries that you need are preinstalled in the notebook environment and only need to be loaded.
#
# Run the following cell to load the libraries you will work with in this notebook:

# %%
# PySpark Machine Learning Library
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.sql import Row, SQLContext

import os
import sys
from pyspark import SparkConf
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.types import *

from pyspark.mllib.classification import LogisticRegressionWithSGD
from pyspark.mllib.regression import LabeledPoint
from numpy import array

from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Library for confusion matrix, precision, test error
from pyspark.mllib.evaluation import MulticlassMetrics
# Library For Area under ROC curve and Area under precision-recall curve
from pyspark.mllib.evaluation import BinaryClassificationMetrics

# Assign resources to the application
sqlContext = SQLContext(sc)

# packages for data analysis
import numpy as np
import pandas as pd

# %%
# The data will be loaded into an array.
# This is the summary of the data structure, including the column position and name.
# The first filed starts from position 0. 

# 0 PatientID    - Patient identification number
# 1 male  -  male or female
# 2 age
# 3 education - should exclude
# 4 currentSmoker - whether or not the patient is a current smoker
# 5 cigsPerDay - the number of cigarettes that the person smoked on average in one day.
# 6 BPMeds
# 7 prevalentStroke - whether or not the patient had previously had a stroke   -  skewed
# 8 prevalentHyp - whether or not the patient was hypertensive
# 9 diabetes   -  skewed
# 10 totChol - total cholesterol level
# 11 sysBP
# 12 diaBP
# 13 BMI
# 14 heartRate
# 15 glucose
# 16 TenYearCHD - 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”)

# Label is a target variable. PersonInfo is a list of independent variables besides unique identifier

LabeledDocument = Row("PersonID", "PersonInfo", "label")

# Define a function that parses each raw in CSV file and returns an object of type LabeledDocument

def parseDocument(line):
    values = [str(x) for x in line.split(',')] 
    if (values[16]>'0'):
      TenYearCHD = 1.0
    else:
      TenYearCHD = 0.0
        
    textValue = str(values[1]) + " " + str(values[2])+" " + str(values[3])+" " + str(values[4])+" " + str(values[5])+" " + str(values[6])+" " + str(values[7])+" " + str(values[8])+" " + str(values[9])+" " + str(values[10])+" " + str(values[11])+" " + str(values[12])+" " + str(values[13])+" " + str(values[14])+" " + str(values[15])
 #   textValue = str(values[1]) + " " + str(values[2])+" " + str(values[3])+" "  + str(values[5])+" "   + str(values[8])+" " + str(values[10])+" " + str(values[11])+" " + str(values[12])+" " + str(values[15])
 #   textValue = str(values[1]) + " " + str(values[2])+" " + str(values[3])+" "  + str(values[5])+" "   + str(values[8])+" " + str(values[10])+" " + str(values[11])+" " + str(values[13])+" " + str(values[15])
  #  textValue = str(values[1]) + " " + str(values[2])+" " + str(values[3])
 #   textValue = str(values[1]) + " " + str(values[3])+" "  + str(values[5])+" "   + str(values[8])+" " + str(values[10])+" " + str(values[11])+" " + str(values[13])+" " + str(values[15])

    return LabeledDocument(values[0], textValue, TenYearCHD)

# %% [markdown]
# <a id="access_data"></a>
# ## Access Data
# To read a file from Object Storage, you must setup the Spark configuration with your Object Storage credentials.
#
# To do this, click on the cell below and select the **Insert to code > Insert Spark Session DataFrame** function from the Files tab below the data file you want to work with.

# %% [markdown]
# <div class="alert alert-block alert-info">The following code contains the credentials for a file in your IBM Cloud Object Storage. </div>

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# [Row(PatientID=1, male=1, age=39, education=4, currentSmoker=0, cigsPerDay=0, BPMeds=0, prevalentStroke=0, prevalentHyp=0, diabetes=0, totChol=195, sysBP=106.0, diaBP=70.0, BMI=26.97, heartRate=80, glucose=77, TenYearCHD=0),
#  Row(PatientID=2, male=0, age=46, education=2, currentSmoker=0, cigsPerDay=0, BPMeds=0, prevalentStroke=0, prevalentHyp=0, diabetes=0, totChol=250, sysBP=121.0, diaBP=81.0, BMI=28.73, heartRate=95, glucose=76, TenYearCHD=0),
#  Row(PatientID=3, male=1, age=48, education=1, currentSmoker=1, cigsPerDay=20, BPMeds=0, prevalentStroke=0, prevalentHyp=0, diabetes=0, totChol=245, sysBP=127.5, diaBP=80.0, BMI=25.34, heartRate=75, glucose=70, TenYearCHD=0),
#  Row(PatientID=4, male=0, age=61, education=3, currentSmoker=1, cigsPerDay=30, BPMeds=0, prevalentStroke=0, prevalentHyp=1, diabetes=0, totChol=225, sysBP=150.0, diaBP=95.0, BMI=28.58, heartRate=65, glucose=103, TenYearCHD=1),
#  Row(PatientID=5, male=0, age=46, education=3, currentSmoker=1, cigsPerDay=23, BPMeds=0, prevalentStroke=0, prevalentHyp=0, diabetes=0, totChol=285, sysBP=130.0, diaBP=84.0, BMI=23.1, heartRate=85, glucose=85, TenYearCHD=0)]

# %% [markdown]
# <a id="Explore"></a>
# ## Explore Data

# %%
# Infer the data type of each column and convert the data to the inferred data type
df_data_1.printSchema()
# Out:
# root
#  |-- PatientID: integer (nullable = true)
#  |-- male: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- education: integer (nullable = true)
#  |-- currentSmoker: integer (nullable = true)
#  |-- cigsPerDay: integer (nullable = true)
#  |-- BPMeds: integer (nullable = true)
#  |-- prevalentStroke: integer (nullable = true)
#  |-- prevalentHyp: integer (nullable = true)
#  |-- diabetes: integer (nullable = true)
#  |-- totChol: integer (nullable = true)
#  |-- sysBP: double (nullable = true)
#  |-- diaBP: double (nullable = true)
#  |-- BMI: double (nullable = true)
#  |-- heartRate: integer (nullable = true)
#  |-- glucose: integer (nullable = true)
#  |-- TenYearCHD: integer (nullable = true)

# %%
print('Number of Patients', df_data_1.count())
# Out:
# Number of Patients 4240

# %%
df_data_1.describe()
# Out:
# DataFrame[summary: string, PatientID: string, male: string, age: string, education: string, currentSmoker: string, cigsPerDay: string, BPMeds: string, prevalentStroke: string, prevalentHyp: string, diabetes: string, totChol: string, sysBP: string, diaBP: string, BMI: string, heartRate: string, glucose: string, TenYearCHD: string]

# %%
#Number of patients who are at risk and number patients who are not at risk
df_data_1.groupby('TenYearCHD').count().show()
# Out:
# +----------+-----+
# |TenYearCHD|count|
# +----------+-----+
# |         1|  644|
# |         0| 3596|
# +----------+-----+

# %%
#Number of patients who are at risk and number passengers who are not at risk by education
import matplotlib.pyplot as plt
# %matplotlib inline
df_data_1.crosstab('education', 'TenYearCHD').show()
df=df_data_1.crosstab('education', 'TenYearCHD').toPandas()
df.plot.bar(x="education_TenYearCHD", legend=True , title="10 year risk by education")
# Out:
# +--------------------+----+---+
# |education_TenYearCHD|   0|  1|
# +--------------------+----+---+
# |                   0|  89| 16|
# |                   1|1397|323|
# |                   2|1106|147|
# |                   3| 601| 88|
# |                   4| 403| 70|
# +--------------------+----+---+
# <AxesSubplot:title={'center':'10 year risk by education'}, xlabel='education_TenYearCHD'>

# %%
# Average age by risk outcome
PAge=df_data_1.groupby(['TenYearCHD'])\
.agg({"age": "AVG"}).toPandas()
PAge
# Out:
#    TenYearCHD   avg(age)
# 0           1  54.145963
# 1           0  48.762514

# %%
#Age distribution for all patients
df_data_1.toPandas()["age"].plot.hist(x="age", title="Age distribution")
# Out:
# <AxesSubplot:title={'center':'Age distribution'}, ylabel='Frequency'>

# %%
# Age distribution for patients at risk
df_died=df_data_1.select('age', 'TenYearCHD').filter(df_data_1['TenYearCHD']=='1')
pdf_died=df_died.select('age').toPandas()
pdf_died.plot.hist('age',  color='m',legend=False, title="Age distribution for patinets at risk")
# Out:
# <AxesSubplot:title={'center':'Age distribution for patinets at risk'}, ylabel='Frequency'>

# %%
df_data_1.toPandas().columns
# Out:
# Index(['PatientID', 'male', 'age', 'education', 'currentSmoker', 'cigsPerDay',
#        'BPMeds', 'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol',
#        'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df_data_1.toPandas().isnull().sum()
# Out:
# PatientID          0
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df_data_1.toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PatientID        4240 non-null   int32
#  1   male             4240 non-null   int32
#  2   age              4240 non-null   int32
#  3   education        4240 non-null   int32
#  4   currentSmoker    4240 non-null   int32
#  5   cigsPerDay       4240 non-null   int32
#  6   BPMeds           4240 non-null   int32
#  7   prevalentStroke  4240 non-null   int32
#  8   prevalentHyp     4240 non-null   int32
#  9   diabetes         4240 non-null   int32
#  10  totChol          4240 non-null   int32
#  11  sysBP            4240 non-null   float64
#  12  diaBP            4240 non-null   float64
#  13  BMI              4240 non-null   float64
#  14  heartRate        4240 non-null   int32
#  15  glucose          4240 non-null   int32
#  16  TenYearCHD       4240 non-null   int32
# dtypes: float64(3), int32(14)
# memory usage: 331.4 KB

# %%
df_data_1.toPandas().describe()
# Out:
#        PatientID         male          age    education  currentSmoker  \
# count  4240.0000  4240.000000  4240.000000  4240.000000    4240.000000
# mean   2120.5000     0.429245    49.580189     1.930425       0.494104
# std    1224.1269     0.495027     8.572942     1.053026       0.500024
# min       1.0000     0.000000    32.000000     0.000000       0.000000
# 25%    1060.7500     0.000000    42.000000     1.000000       0.000000
# 50%    2120.5000     0.000000    49.000000     2.000000       0.000000
# 75%    3180.2500     1.000000    56.000000     3.000000       1.000000
# max    4240.0000     1.000000    70.000000     4.000000       1.000000
#
#         cigsPerDay       BPMeds  prevalentStroke  prevalentHyp     diabetes  \
# count  4240.000000  4240.000000      4240.000000   4240.000000  4240.000000
# mean      8.944340     0.041745         0.005896      0.310613     0.025708
# std      11.904777     0.200030         0.076569      0.462799     0.158280
# min       0.000000     0.000000         0.000000      0.000000     0.000000
# 25%       0.000000     0.000000         0.000000      0.000000     0.000000
# 50%       0.000000     0.000000         0.000000      0.000000     0.000000
# 75%      20.000000     0.000000         0.000000      1.000000     0.000000
# max      70.000000     1.000000         1.000000      1.000000     1.000000
#
#            totChol        sysBP        diaBP          BMI    heartRate  \
# count  4240.000000  4240.000000  4240.000000  4240.000000  4240.000000
# mean    236.303302   132.354599    82.897759    25.796325    75.876651
# std      44.510888    22.033300    11.910394     4.071621    12.024887
# min     107.000000    83.500000    48.000000    15.540000    44.000000
# 25%     205.000000   117.000000    75.000000    23.070000    68.000000
# 50%     233.000000   128.000000    82.000000    25.380000    75.000000
# 75%     262.000000   144.000000    90.000000    28.032500    83.000000
# max     696.000000   295.000000   142.500000    56.800000   143.000000
#
#            glucose   TenYearCHD
# count  4240.000000  4240.000000
# mean     81.361557     0.151887
# std      23.100408     0.358953
# min      40.000000     0.000000
# 25%      71.000000     0.000000
# 50%      77.000000     0.000000
# 75%      86.000000     0.000000
# max     394.000000     1.000000

# %%
#Draw histogram for all variables
def draw_histograms(dataframe, features, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=20,ax=ax,facecolor='green')
        ax.set_title(feature+" Distribution",color='DarkRed')
        
    fig.tight_layout()  
    plt.show()
draw_histograms(df_data_1.toPandas(), df_data_1.toPandas().columns,6,3)

# %%
import seaborn as sn
sn.pairplot(data=df_data_1.toPandas())

# %%
plt.figure(figsize=(15,15))
sn.heatmap(df_data_1.toPandas().corr(), annot=True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id="Parse"></a>
# ## Parse Data
# Now let's load the data into a `Spark RDD` and output the number of rows and first 5 rows.
# Each project you create has a bucket in your object storage. You may get the bucket name from the project Settings page. Replace the string `BUCKET` to the bucket name

# %%
data = sc.textFile(cos.url('framingham.csv', 'sparktutorial-donotdelete-pr-efg7yskqnasefv'))
print ("Total records in the data set:", data.count())
print ("The first 5 rows")
data.take(5)
# Out:
# Total records in the data set: 4241
# The first 5 rows
# ['PatientID,male,age,education,currentSmoker,cigsPerDay,BPMeds,prevalentStroke,prevalentHyp,diabetes,totChol,sysBP,diaBP,BMI,heartRate,glucose,TenYearCHD',
#  '1,1,39,4,0,0,0,0,0,0,195,106,70,26.97,80,77,0',
#  '2,0,46,2,0,0,0,0,0,0,250,121,81,28.73,95,76,0',
#  '3,1,48,1,1,20,0,0,0,0,245,127.5,80,25.34,75,70,0',
#  '4,0,61,3,1,30,0,0,1,0,225,150,95,28.58,65,103,1']

# %% [markdown]
# Create DataFrame from RDD

# %%
#Parse and Load the data into a dataframe. The code calls the parsing function defined above
documents = data.filter(lambda s: "PatientID" not in s).map(parseDocument)
heart_df = documents.toDF() # ToDataFrame
print ("Number of records: " + str(heart_df.count()))
print ( "First 5 records: ")
heart_df.take(5)
# Out:
# Number of records: 4240
# First 5 records:
# [Row(PersonID='1', PersonInfo='1 39 4 0 0 0 0 0 0 195 106 70 26.97 80 77', label=0.0),
#  Row(PersonID='2', PersonInfo='0 46 2 0 0 0 0 0 0 250 121 81 28.73 95 76', label=0.0),
#  Row(PersonID='3', PersonInfo='1 48 1 1 20 0 0 0 0 245 127.5 80 25.34 75 70', label=0.0),
#  Row(PersonID='4', PersonInfo='0 61 3 1 30 0 0 1 0 225 150 95 28.58 65 103', label=1.0),
#  Row(PersonID='5', PersonInfo='0 46 3 1 23 0 0 0 0 285 130 84 23.1 85 85', label=0.0)]

# %% [markdown]
# <a id="training_test"></a>
# ## Split Data into Training and Test set
#
# We divide the data into training and test set.  The training set is used to build the model to be used on future data, and the test set is used to evaluate the model.

# %%
# Divide the data into training and test set
(train, test) = heart_df.randomSplit([0.7, 0.3])
print ("Number of records in the training set: " + str(train.count()))
print ("Number of records in the test set: " + str(test.count()))
# Output first 20 records in the training set
print ("First 20 records in the training set: ")
train.show()
# Out:
# Number of records in the training set: 2908
# Number of records in the test set: 1332
# First 20 records in the training set:
# +--------+--------------------+-----+
# |PersonID|          PersonInfo|label|
# +--------+--------------------+-----+
# |      10|1 43 1 1 30 0 0 1...|  0.0|
# |     100|0 56 1 1 15 0 0 0...|  0.0|
# |    1000|0 37 2 0 0 0 0 0 ...|  0.0|
# |    1001|0 41 2 0 0 0 0 0 ...|  0.0|
# |    1002|1 46 3 0 0 0 0 0 ...|  0.0|
# |    1003|1 60 1 0 0 1 0 1 ...|  0.0|
# |    1004|0 64 1 0 0 0 0 1 ...|  0.0|
# |    1006|1 50 1 0 0 0 0 0 ...|  0.0|
# |    1007|0 38 4 0 0 0 0 0 ...|  0.0|
# |    1009|1 53 1 1 20 0 0 1...|  0.0|
# |     101|0 47 2 1 20 0 0 0...|  0.0|
# |    1010|0 51 2 1 1 0 0 0 ...|  0.0|
# |    1011|1 42 1 1 30 0 0 0...|  0.0|
# |    1012|1 58 1 1 1 0 0 0 ...|  0.0|
# |    1014|1 53 2 0 0 0 0 0 ...|  0.0|
# |    1015|1 58 4 0 0 0 0 0 ...|  0.0|
# |    1016|1 60 1 1 5 0 0 0 ...|  0.0|
# |    1018|1 59 3 0 0 0 0 0 ...|  0.0|
# |     102|0 60 3 0 0 0 0 1 ...|  0.0|
# |    1021|1 35 2 0 0 0 0 0 ...|  0.0|
# +--------+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# <a id="build_model"></a>
# ## Build Logistic Regression Model
#
# We use the Pipeline of SparkML to build the Logistic Regression Model

# %%
# set up Logistic Regression using Pipeline of SparkML
tokenizer = Tokenizer(inputCol="PersonInfo", outputCol="words")
hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
lr = LogisticRegression(maxIter=10, regParam=0.01)
pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])

# %%
# set up Logistic Regression Model
# the stages are executed in order
model = pipeline.fit(train)
#[stage.coefficients for stage in model.stages if hasattr(stage, "coefficients")]
# model.stages[2].intercept

# %% [markdown]
# <a id="test_data"></a>
# ## Predict for Test data

# %%
# Make predictions for test data and print columns of interest
prediction = model.transform(test)
selected = prediction.select("PersonInfo", "prediction", "probability")
for row in selected.collect():
    print (row)
# Out:
# Row(PersonInfo='1 39 4 0 0 0 0 0 0 195 106 70 26.97 80 77', prediction=0.0, probability=DenseVector([0.9982, 0.0018]))
# Row(PersonInfo='0 43 1 0 0 0 0 0 0 175 117 67 22.36 58 70', prediction=0.0, probability=DenseVector([0.9567, 0.0433]))
# Row(PersonInfo='0 56 3 0 0 0 0 0 0 310 142 94 31.1 83 65', prediction=0.0, probability=DenseVector([0.6982, 0.3018]))
# Row(PersonInfo='0 54 2 1 20 0 0 0 0 187 133 88 31.82 75 77', prediction=0.0, probability=DenseVector([0.991, 0.009]))
# Row(PersonInfo='1 62 3 0 0 0 0 0 0 332 119.5 74 28.5 68 92', prediction=1.0, probability=DenseVector([0.2953, 0.7047]))
# Row(PersonInfo='0 53 2 0 0 0 0 1 0 232 147 71.5 25.45 85 74', prediction=0.0, probability=DenseVector([0.969, 0.031]))
# Row(PersonInfo='0 42 2 1 10 0 0 0 0 242 100 66 21.85 75 75', prediction=0.0, probability=DenseVector([0.7742, 0.2258]))
# Row(PersonInfo='0 57 1 0 0 0 0 0 0 277 133 84 36.21 62 74', prediction=0.0, probability=DenseVector([0.9818, 0.0182]))
# Row(PersonInfo='0 46 3 0 0 0 0 0 0 197 105.5 67 23.14 60 69', prediction=0.0, probability=DenseVector([0.7527, 0.2473]))
# Row(PersonInfo='1 45 2 1 20 0 0 0 1 279 138 86 30.63 80 144', prediction=0.0, probability=DenseVector([0.9797, 0.0203]))
# Row(PersonInfo='1 45 4 1 3 0 0 1 0 218 145 90 26.65 76 70', prediction=0.0, probability=DenseVector([0.8236, 0.1764]))
# Row(PersonInfo='0 42 4 0 0 0 0 0 0 183 111 71 19.78 66 81', prediction=0.0, probability=DenseVector([0.9975, 0.0025]))
# Row(PersonInfo='0 62 3 1 20 0 0 0 0 264 142 90 31.78 95 97', prediction=0.0, probability=DenseVector([0.6846, 0.3154]))
# Row(PersonInfo='1 48 1 0 0 0 0 0 0 270 131 88 27.13 63 55', prediction=1.0, probability=DenseVector([0.3199, 0.6801]))
# Row(PersonInfo='0 55 0 0 0 0 0 0 0 269 112.5 72.5 23.45 60 80', prediction=0.0, probability=DenseVector([0.9992, 0.0008]))
# Row(PersonInfo='1 45 2 1 20 0 0 0 0 207 117 80 20.17 75 59', prediction=0.0, probability=DenseVector([0.9873, 0.0127]))
# Row(PersonInfo='1 61 1 0 0 0 0 1 0 201 164.5 93.5 27.73 78 95', prediction=0.0, probability=DenseVector([0.9969, 0.0031]))
# Row(PersonInfo='0 49 1 1 0 0 0 0 0 280 120 80 22.33 90 75', prediction=0.0, probability=DenseVector([0.9954, 0.0046]))
# Row(PersonInfo='1 42 2 0 0 0 0 1 0 164 141.5 98 32.52 72 76', prediction=0.0, probability=DenseVector([0.9829, 0.0171]))
# Row(PersonInfo='0 40 1 0 0 0 0 0 0 187 105 74 23.26 80 69', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='0 37 4 0 0 0 0 0 0 169 117.5 77.5 28.44 90 75', prediction=0.0, probability=DenseVector([0.9997, 0.0003]))
# Row(PersonInfo='1 52 1 0 0 0 0 0 0 200 114 77 28.28 66 84', prediction=0.0, probability=DenseVector([0.9841, 0.0159]))
# Row(PersonInfo='0 45 0 1 20 0 0 0 0 215 107 75 22.14 79 105', prediction=0.0, probability=DenseVector([0.9789, 0.0211]))
# Row(PersonInfo='0 65 1 0 0 0 0 0 0 276 124 70 25.61 76 75', prediction=0.0, probability=DenseVector([0.999, 0.001]))
# Row(PersonInfo='0 42 0 1 9 0 0 0 0 165 139 91 26.54 83 83', prediction=0.0, probability=DenseVector([0.9964, 0.0036]))
# Row(PersonInfo='1 48 1 0 0 0 0 0 0 181 153 93 29.34 103 88', prediction=0.0, probability=DenseVector([0.9064, 0.0936]))
# Row(PersonInfo='0 59 3 0 0 0 0 1 0 273 145 90 23.94 78 82', prediction=0.0, probability=DenseVector([0.8331, 0.1669]))
# Row(PersonInfo='0 46 2 0 0 0 0 0 0 253 118 79 26.61 85 83', prediction=0.0, probability=DenseVector([0.9745, 0.0255]))
# Row(PersonInfo='0 40 1 1 9 0 0 0 0 239 118 78 23.48 85 75', prediction=0.0, probability=DenseVector([0.9899, 0.0101]))
# Row(PersonInfo='1 47 2 1 15 0 0 0 0 253 137 87 24.5 80 81', prediction=1.0, probability=DenseVector([0.4167, 0.5833]))
# Row(PersonInfo='1 43 4 1 40 0 0 0 0 263 114 81 25.68 70 74', prediction=0.0, probability=DenseVector([0.9987, 0.0013]))
# Row(PersonInfo='1 51 1 1 20 0 0 0 0 219 125 71 21.19 77 75', prediction=0.0, probability=DenseVector([0.993, 0.007]))
# Row(PersonInfo='0 37 1 1 5 0 0 0 0 279 110 72.5 24.89 67 70', prediction=0.0, probability=DenseVector([0.9894, 0.0106]))
# Row(PersonInfo='0 50 4 0 0 0 0 0 0 274 125 87 21.67 75 73', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='0 38 3 0 0 0 0 0 0 174 101 68 27.47 85 75', prediction=0.0, probability=DenseVector([0.9758, 0.0242]))
# Row(PersonInfo='0 60 4 1 20 0 0 1 0 352 149 73 25.96 80 79', prediction=1.0, probability=DenseVector([0.1768, 0.8232]))
# Row(PersonInfo='1 57 4 0 0 1 0 1 0 195 162 108 32.65 85 73', prediction=0.0, probability=DenseVector([0.9726, 0.0274]))
# Row(PersonInfo='0 52 2 0 0 0 0 1 1 600 159.5 94 28.27 78 140', prediction=0.0, probability=DenseVector([0.9837, 0.0163]))
# Row(PersonInfo='0 63 3 0 0 0 0 0 0 241 143.5 89 26.45 69 80', prediction=0.0, probability=DenseVector([0.7699, 0.2301]))
# Row(PersonInfo='0 66 2 0 0 0 0 1 0 238 140 80 26.69 69 83', prediction=0.0, probability=DenseVector([0.9997, 0.0003]))
# Row(PersonInfo='1 58 1 1 15 0 0 0 0 272 127.5 79.5 26.37 78 66', prediction=0.0, probability=DenseVector([0.9971, 0.0029]))
# Row(PersonInfo='0 67 1 1 6 1 0 0 0 200 120 67 32.77 86 75', prediction=0.0, probability=DenseVector([0.9933, 0.0067]))
# Row(PersonInfo='1 64 4 0 0 0 0 0 1 251 133 72.5 24.28 65 86', prediction=0.0, probability=DenseVector([0.9866, 0.0134]))
# Row(PersonInfo='0 42 3 1 10 0 0 0 0 253 109 74 24.38 88 60', prediction=0.0, probability=DenseVector([0.9779, 0.0221]))
# Row(PersonInfo='1 48 4 0 0 0 0 0 0 233 138 88.5 23.62 86 68', prediction=0.0, probability=DenseVector([0.8877, 0.1123]))
# Row(PersonInfo='0 51 2 0 0 0 0 1 0 206 146 77 23.58 87 90', prediction=0.0, probability=DenseVector([0.7128, 0.2872]))
# Row(PersonInfo='1 40 2 1 30 0 0 1 0 282 130 80 23.9 66 68', prediction=0.0, probability=DenseVector([0.9971, 0.0029]))
# Row(PersonInfo='0 45 4 1 20 0 0 0 0 192 132 79 24.53 68 112', prediction=0.0, probability=DenseVector([0.9983, 0.0017]))
# Row(PersonInfo='0 64 1 0 0 0 0 1 0 282 158 105 24.37 75 71', prediction=0.0, probability=DenseVector([0.9054, 0.0946]))
# Row(PersonInfo='1 44 2 1 35 0 0 1 0 217 144 99 25.16 68 60', prediction=0.0, probability=DenseVector([0.9962, 0.0038]))
# Row(PersonInfo='0 63 3 0 0 0 0 1 0 315 156 90 25.92 64 74', prediction=0.0, probability=DenseVector([0.999, 0.001]))
# Row(PersonInfo='1 55 1 1 25 0 0 0 0 270 129 82 27.63 88 60', prediction=0.0, probability=DenseVector([0.9299, 0.0701]))
# Row(PersonInfo='0 41 1 0 0 0 0 1 0 265 136 98 42.15 90 71', prediction=0.0, probability=DenseVector([0.9702, 0.0298]))
# Row(PersonInfo='1 50 1 0 0 0 0 1 0 257 127 82 32.23 75 117', prediction=0.0, probability=DenseVector([0.9434, 0.0566]))
# Row(PersonInfo='0 41 2 1 3 0 0 0 0 223 119 73 24.22 72 77', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='0 53 4 0 0 0 0 0 0 291 114 81 26.21 70 79', prediction=1.0, probability=DenseVector([0.1108, 0.8892]))
# Row(PersonInfo='1 60 1 0 0 0 0 1 0 278 160.5 96 26.4 55 75', prediction=0.0, probability=DenseVector([0.9072, 0.0928]))
# Row(PersonInfo='0 53 3 0 0 0 0 0 0 245 102 68 23.01 60 75', prediction=0.0, probability=DenseVector([0.9904, 0.0096]))
# Row(PersonInfo='0 62 2 0 0 0 0 1 0 304 165 91 26.97 80 81', prediction=0.0, probability=DenseVector([0.8055, 0.1945]))
# Row(PersonInfo='0 37 2 1 5 0 0 0 0 185 100 68 18.38 70 72', prediction=0.0, probability=DenseVector([0.9734, 0.0266]))
# Row(PersonInfo='1 38 2 1 43 0 0 1 0 170 130 94 23.9 110 75', prediction=0.0, probability=DenseVector([0.9931, 0.0069]))
# Row(PersonInfo='0 64 2 1 3 0 0 0 0 315 135 80 25.23 103 89', prediction=0.0, probability=DenseVector([0.9993, 0.0007]))
# Row(PersonInfo='1 50 1 1 20 0 0 0 0 261 114 64 22.32 85 71', prediction=0.0, probability=DenseVector([0.9805, 0.0195]))
# Row(PersonInfo='0 63 3 0 0 0 0 1 0 306 177 96 32.51 90 126', prediction=1.0, probability=DenseVector([0.0064, 0.9936]))
# Row(PersonInfo='1 36 4 0 0 0 0 0 0 210 112 85.5 21.93 71 77', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='0 64 1 0 0 0 0 0 0 280 127 77 30.39 56 78', prediction=0.0, probability=DenseVector([0.9558, 0.0442]))
# Row(PersonInfo='0 62 1 0 0 0 0 1 0 231 184 90 26.03 70 75', prediction=0.0, probability=DenseVector([0.9787, 0.0213]))
# Row(PersonInfo='1 40 1 1 10 0 0 0 0 304 125 86 30.07 80 84', prediction=0.0, probability=DenseVector([0.7654, 0.2346]))
# Row(PersonInfo='0 47 1 1 20 0 0 0 0 195 134 81 21.4 85 75', prediction=0.0, probability=DenseVector([0.9639, 0.0361]))
# Row(PersonInfo='0 42 3 1 20 0 0 0 0 304 119 76 32.52 64 80', prediction=0.0, probability=DenseVector([0.6134, 0.3866]))
# Row(PersonInfo='1 52 1 0 0 0 0 0 0 206 110 78 33.03 65 62', prediction=0.0, probability=DenseVector([0.5191, 0.4809]))
# Row(PersonInfo='1 42 4 0 0 0 0 1 0 245 142.5 85 35.45 62 75', prediction=0.0, probability=DenseVector([0.9651, 0.0349]))
# Row(PersonInfo='0 52 1 1 1 0 0 0 0 234 111 81 22.35 70 77', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='0 58 1 0 0 0 0 0 0 218 138.5 87.5 22.91 73 75', prediction=0.0, probability=DenseVector([0.7481, 0.2519]))
# Row(PersonInfo='0 43 3 0 0 0 0 0 0 209 115 75 27.99 80 90', prediction=0.0, probability=DenseVector([0.7462, 0.2538]))
# Row(PersonInfo='1 44 2 0 0 0 0 1 0 248 174 110 31.74 75 100', prediction=0.0, probability=DenseVector([0.9328, 0.0672]))
# Row(PersonInfo='0 38 2 1 10 0 0 0 0 155 96 61 24.19 60 68', prediction=0.0, probability=DenseVector([0.9762, 0.0238]))
# Row(PersonInfo='1 41 1 0 0 0 0 0 0 255 120.5 85.5 30.85 100 79', prediction=0.0, probability=DenseVector([0.9646, 0.0354]))
# Row(PersonInfo='1 40 1 0 0 0 0 0 0 137 127 82 27.04 60 71', prediction=1.0, probability=DenseVector([0.3307, 0.6693]))
# Row(PersonInfo='0 38 2 1 9 0 0 0 0 160 102.5 67.5 21.16 90 68', prediction=0.0, probability=DenseVector([0.9999, 0.0001]))
# Row(PersonInfo='0 45 3 0 0 0 0 0 0 186 104.5 71 31.35 55 75', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='0 45 3 1 9 0 0 1 0 261 140 88 21.44 70 78', prediction=0.0, probability=DenseVector([0.9451, 0.0549]))
# Row(PersonInfo='0 55 2 0 0 0 0 1 0 183 158 86 24.45 70 102', prediction=0.0, probability=DenseVector([0.8729, 0.1271]))
# Row(PersonInfo='1 47 3 1 15 0 0 1 0 220 127 93 30.7 82 57', prediction=0.0, probability=DenseVector([0.8374, 0.1626]))
# Row(PersonInfo='1 58 4 1 20 0 0 1 0 213 162 99 28.3 60 70', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='1 63 1 0 0 0 0 0 0 252 135.5 80 28.78 60 79', prediction=0.0, probability=DenseVector([0.9976, 0.0024]))
# Row(PersonInfo='1 52 1 0 0 0 0 1 0 318 144 85 27.66 78 64', prediction=0.0, probability=DenseVector([0.9904, 0.0096]))
# Row(PersonInfo='1 58 1 0 0 0 0 0 0 220 143 104 29.85 75 87', prediction=0.0, probability=DenseVector([0.8024, 0.1976]))
# Row(PersonInfo='0 46 3 0 0 0 0 0 0 190 128 74 23.01 95 78', prediction=0.0, probability=DenseVector([0.9975, 0.0025]))
# Row(PersonInfo='0 54 1 0 0 0 0 0 0 272 146 95 23.66 72 80', prediction=0.0, probability=DenseVector([0.9892, 0.0108]))
# Row(PersonInfo='0 53 1 1 3 0 0 1 0 268 136.5 94.5 25.51 100 75', prediction=0.0, probability=DenseVector([0.9942, 0.0058]))
# Row(PersonInfo='1 53 1 1 30 0 0 0 0 253 121 85.5 28.52 80 68', prediction=1.0, probability=DenseVector([0.1732, 0.8268]))
# Row(PersonInfo='1 64 1 1 20 0 0 0 0 214 116 77 22.48 72 71', prediction=0.0, probability=DenseVector([0.9779, 0.0221]))
# Row(PersonInfo='1 48 2 1 40 0 0 0 0 226 117.5 80 26.18 60 66', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='1 56 1 1 15 0 0 0 0 195 108 70 22.92 75 117', prediction=1.0, probability=DenseVector([0.2156, 0.7844]))
# Row(PersonInfo='0 40 2 0 0 0 0 0 0 233 108.5 75 28.3 60 73', prediction=0.0, probability=DenseVector([0.9992, 0.0008]))
# Row(PersonInfo='1 42 3 1 0 0 0 0 0 225 122.5 80 25.54 90 90', prediction=0.0, probability=DenseVector([0.9975, 0.0025]))
# Row(PersonInfo='1 47 1 0 0 0 0 0 0 197 115 81 22.41 50 66', prediction=0.0, probability=DenseVector([0.996, 0.004]))
# Row(PersonInfo='0 50 1 0 0 0 0 1 0 240 163 105 31.37 89 75', prediction=0.0, probability=DenseVector([0.9597, 0.0403]))
# Row(PersonInfo='0 55 2 1 20 0 0 0 0 250 138 87 25.33 95 75', prediction=0.0, probability=DenseVector([0.8748, 0.1252]))
# Row(PersonInfo='0 41 2 0 0 0 0 0 0 213 112 73 24.81 62 74', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='0 63 1 0 0 0 0 1 0 226 172.5 98 26.47 87 81', prediction=0.0, probability=DenseVector([0.8929, 0.1071]))
# Row(PersonInfo='1 55 1 0 0 0 0 1 1 180 174 100 26.83 71 78', prediction=0.0, probability=DenseVector([0.9064, 0.0936]))
# Row(PersonInfo='1 46 2 1 43 0 0 1 0 259 125 89 24.8 100 57', prediction=0.0, probability=DenseVector([0.853, 0.147]))
# Row(PersonInfo='1 62 1 0 0 0 0 0 0 216 126 82 21.18 69 69', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='1 59 1 1 20 0 0 1 0 280 164 81 29.76 80 68', prediction=0.0, probability=DenseVector([0.8916, 0.1084]))
# Row(PersonInfo='1 53 1 1 30 0 0 0 0 244 106 67.5 21.84 88 65', prediction=0.0, probability=DenseVector([0.9952, 0.0048]))
# Row(PersonInfo='1 59 1 1 20 0 0 0 0 206 115 70 24.79 84 76', prediction=0.0, probability=DenseVector([0.6691, 0.3309]))
# Row(PersonInfo='1 60 1 0 0 0 0 0 0 183 114 70 23.56 75 59', prediction=0.0, probability=DenseVector([0.9811, 0.0189]))
# Row(PersonInfo='1 43 4 1 0 0 0 0 0 222 109.5 69 25.5 75 65', prediction=0.0, probability=DenseVector([0.9817, 0.0183]))
# Row(PersonInfo='0 35 2 1 5 0 0 0 0 186 106 78 24.73 60 70', prediction=0.0, probability=DenseVector([0.9986, 0.0014]))
# Row(PersonInfo='0 57 2 0 0 0 0 0 0 239 127 81 21.85 75 87', prediction=0.0, probability=DenseVector([0.8164, 0.1836]))
# Row(PersonInfo='0 60 1 0 0 0 0 0 0 277 126 70 25.13 60 100', prediction=0.0, probability=DenseVector([0.9811, 0.0189]))
# Row(PersonInfo='0 53 1 1 20 0 0 1 0 235 154 98 26.91 80 65', prediction=0.0, probability=DenseVector([0.9267, 0.0733]))
# Row(PersonInfo='0 36 3 0 0 0 0 0 0 230 112.5 73.5 22.36 63 65', prediction=0.0, probability=DenseVector([0.89, 0.11]))
# Row(PersonInfo='0 59 2 1 1 0 0 0 0 236 139 84 22.7 63 75', prediction=1.0, probability=DenseVector([0.4522, 0.5478]))
# Row(PersonInfo='1 59 2 1 30 0 0 0 0 303 134 89 24.07 78 75', prediction=1.0, probability=DenseVector([0.2598, 0.7402]))
# Row(PersonInfo='1 62 1 0 0 0 0 0 1 237 114 72 25.65 62 89', prediction=0.0, probability=DenseVector([0.9747, 0.0253]))
# Row(PersonInfo='0 48 1 1 25 0 0 0 1 304 102 66.5 28.9 100 66', prediction=1.0, probability=DenseVector([0.3765, 0.6235]))
# Row(PersonInfo='1 52 1 1 25 0 0 0 0 271 121 73 21.85 70 86', prediction=0.0, probability=DenseVector([0.5061, 0.4939]))
# Row(PersonInfo='0 49 1 0 0 0 0 0 0 211 103.5 66.5 24.17 75 87', prediction=1.0, probability=DenseVector([0.0287, 0.9713]))
# Row(PersonInfo='0 42 2 0 0 0 0 1 0 230 142.5 97.5 29.94 75 75', prediction=0.0, probability=DenseVector([0.9916, 0.0084]))
# Row(PersonInfo='0 59 3 0 0 0 0 0 0 292 114 84 27.39 68 72', prediction=0.0, probability=DenseVector([0.8444, 0.1556]))
# Row(PersonInfo='1 33 2 0 0 0 0 1 0 165 141.5 95 26.74 54 77', prediction=0.0, probability=DenseVector([0.9473, 0.0527]))
# Row(PersonInfo='1 40 1 0 0 0 0 0 0 204 115 83 25.05 75 76', prediction=0.0, probability=DenseVector([0.9689, 0.0311]))
# Row(PersonInfo='1 66 1 0 0 0 0 1 0 253 163 86 24.35 70 91', prediction=0.0, probability=DenseVector([0.9628, 0.0372]))
# Row(PersonInfo='1 46 1 1 30 0 0 0 0 270 131 81 26.4 75 83', prediction=0.0, probability=DenseVector([0.8094, 0.1906]))
# Row(PersonInfo='0 41 2 1 20 0 0 0 0 235 144 88 24.16 95 82', prediction=0.0, probability=DenseVector([0.9342, 0.0658]))
# Row(PersonInfo='0 56 1 0 0 0 0 0 0 259 138 87 30.73 60 75', prediction=0.0, probability=DenseVector([0.8429, 0.1571]))
# Row(PersonInfo='0 65 4 0 0 0 0 0 0 289 149.5 78 25.37 70 86', prediction=0.0, probability=DenseVector([0.9992, 0.0008]))
# Row(PersonInfo='0 55 2 0 0 0 0 1 0 340 140 83 26.18 75 83', prediction=0.0, probability=DenseVector([0.9945, 0.0055]))
# Row(PersonInfo='0 43 2 0 0 1 0 1 0 234 127 88 33.17 85 75', prediction=0.0, probability=DenseVector([0.9962, 0.0038]))
# Row(PersonInfo='1 61 2 0 0 0 0 0 0 246 124 70 25.63 55 78', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='0 66 2 0 0 0 0 0 0 305 138 86 20.74 75 62', prediction=0.0, probability=DenseVector([0.8526, 0.1474]))
# Row(PersonInfo='1 42 0 1 30 0 0 0 0 224 127.5 89 29.84 79 75', prediction=0.0, probability=DenseVector([0.9991, 0.0009]))
# Row(PersonInfo='0 42 3 1 20 0 0 0 0 175 132 86 20.53 80 88', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='1 43 4 0 0 0 0 0 0 262 121 79 24.01 85 87', prediction=0.0, probability=DenseVector([0.9863, 0.0137]))
# Row(PersonInfo='0 41 3 1 30 0 0 1 0 187 154 100 20.5 66 78', prediction=0.0, probability=DenseVector([0.8625, 0.1375]))
# Row(PersonInfo='0 42 1 1 15 0 0 0 0 228 131 85 25.08 72 75', prediction=0.0, probability=DenseVector([0.9984, 0.0016]))
# Row(PersonInfo='0 41 3 0 0 1 0 1 0 332 124 88 31.31 65 84', prediction=0.0, probability=DenseVector([0.9859, 0.0141]))
# Row(PersonInfo='1 63 1 1 20 0 0 1 0 252 149 90 33.49 82 83', prediction=0.0, probability=DenseVector([0.7181, 0.2819]))
# Row(PersonInfo='0 48 3 1 3 0 0 0 0 246 129 86 25.04 80 87', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='1 40 4 1 20 0 0 0 0 229 137 85 35.2 66 55', prediction=0.0, probability=DenseVector([0.9967, 0.0033]))
# Row(PersonInfo='1 43 2 1 20 0 0 0 0 153 130 83.5 19.84 63 75', prediction=0.0, probability=DenseVector([0.998, 0.002]))
# Row(PersonInfo='0 55 1 0 0 0 0 0 0 286 138 82 24.27 80 90', prediction=0.0, probability=DenseVector([0.9969, 0.0031]))
# Row(PersonInfo='0 63 2 0 0 0 0 0 0 192 143 87 23.64 75 100', prediction=0.0, probability=DenseVector([0.9901, 0.0099]))
# Row(PersonInfo='1 36 4 0 0 0 0 0 0 234 133 88 26.78 58 100', prediction=0.0, probability=DenseVector([0.9928, 0.0072]))
# Row(PersonInfo='1 39 1 1 40 0 0 0 0 251 115 77 24.01 65 98', prediction=0.0, probability=DenseVector([0.971, 0.029]))
# Row(PersonInfo='0 51 1 1 15 0 0 0 0 345 142 88 19.05 80 73', prediction=0.0, probability=DenseVector([0.9879, 0.0121]))
# Row(PersonInfo='0 57 3 0 0 0 0 0 0 210 131 85 26.59 70 77', prediction=0.0, probability=DenseVector([0.981, 0.019]))
# Row(PersonInfo='1 41 2 1 20 0 0 1 0 245 146 86 24.5 80 72', prediction=0.0, probability=DenseVector([0.6578, 0.3422]))
# Row(PersonInfo='1 42 3 1 20 0 0 0 0 231 123 87 21.48 75 44', prediction=0.0, probability=DenseVector([0.9963, 0.0037]))
# Row(PersonInfo='0 38 3 1 5 0 0 0 0 187 118 78 30.06 64 63', prediction=0.0, probability=DenseVector([0.9902, 0.0098]))
# Row(PersonInfo='0 41 1 1 15 0 0 0 0 190 95 57 20 75 77', prediction=0.0, probability=DenseVector([0.8667, 0.1333]))
# Row(PersonInfo='0 38 2 1 7 0 0 0 0 160 95 65 21.99 72 77', prediction=0.0, probability=DenseVector([0.8346, 0.1654]))
# Row(PersonInfo='1 45 3 1 23 0 0 0 0 263 115 76 24.94 68 78', prediction=0.0, probability=DenseVector([0.9993, 0.0007]))
# Row(PersonInfo='1 40 3 0 0 0 0 0 0 154 117.5 72.5 26.82 80 87', prediction=0.0, probability=DenseVector([0.9999, 0.0001]))
# Row(PersonInfo='0 52 3 0 0 0 0 0 0 275 137 85 25.89 70 75', prediction=0.0, probability=DenseVector([0.9658, 0.0342]))
# Row(PersonInfo='1 51 3 1 20 0 0 1 0 260 123 72 26.83 65 65', prediction=0.0, probability=DenseVector([0.8877, 0.1123]))
# Row(PersonInfo='1 39 1 0 0 0 0 0 0 213 130 72 22.32 80 78', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='0 51 2 0 0 0 0 0 0 239 127.5 77.5 26.65 70 79', prediction=0.0, probability=DenseVector([0.9997, 0.0003]))
# Row(PersonInfo='1 43 1 1 25 0 0 0 0 201 121 82 23.84 70 91', prediction=0.0, probability=DenseVector([0.7989, 0.2011]))
# Row(PersonInfo='0 48 1 0 0 0 0 0 0 250 117 81 27.04 80 65', prediction=1.0, probability=DenseVector([0.3331, 0.6669]))
# Row(PersonInfo='0 59 1 0 0 0 0 1 0 260 162.5 105 24.39 75 72', prediction=0.0, probability=DenseVector([0.9391, 0.0609]))
# Row(PersonInfo='0 48 2 0 0 0 0 0 0 231 115 69 25.48 90 77', prediction=0.0, probability=DenseVector([0.9999, 0.0001]))
# Row(PersonInfo='1 54 1 1 0 0 0 0 0 219 110 72 26.05 95 86', prediction=0.0, probability=DenseVector([0.7162, 0.2838]))
# Row(PersonInfo='1 39 1 1 60 0 0 0 0 215 112 65 23.6 59 78', prediction=0.0, probability=DenseVector([0.9563, 0.0437]))
# Row(PersonInfo='0 58 2 0 0 0 0 1 0 249 151 97.5 22.88 75 84', prediction=0.0, probability=DenseVector([0.9463, 0.0537]))
# Row(PersonInfo='0 65 1 0 0 0 0 0 0 246 119 76 19.83 75 156', prediction=0.0, probability=DenseVector([0.8912, 0.1088]))
# Row(PersonInfo='0 59 1 0 0 0 0 0 0 246 135 70 18.43 80 107', prediction=0.0, probability=DenseVector([0.991, 0.009]))
# Row(PersonInfo='1 54 2 1 30 0 0 0 0 215 117.5 70.5 26.77 60 75', prediction=0.0, probability=DenseVector([0.9589, 0.0411]))
# Row(PersonInfo='0 44 1 0 0 0 0 0 0 206 121 81 24.12 64 77', prediction=1.0, probability=DenseVector([0.4348, 0.5652]))
# Row(PersonInfo='1 59 4 0 0 0 0 0 0 237 111 80 29.77 65 72', prediction=0.0, probability=DenseVector([0.9975, 0.0025]))
# Row(PersonInfo='1 50 1 1 60 0 0 1 0 340 134 95 30.46 85 86', prediction=0.0, probability=DenseVector([0.9872, 0.0128]))
# Row(PersonInfo='0 54 3 0 0 0 0 1 0 258 148 93 20.51 74 95', prediction=0.0, probability=DenseVector([0.9803, 0.0197]))
# Row(PersonInfo='1 41 4 0 0 0 0 1 0 206 124 90 30.69 75 83', prediction=0.0, probability=DenseVector([0.8886, 0.1114]))
# Row(PersonInfo='0 60 2 0 0 0 0 1 0 334 132 94 25.38 80 98', prediction=0.0, probability=DenseVector([0.8615, 0.1385]))
# Row(PersonInfo='0 57 0 0 0 1 0 1 0 190 155 85 26.08 55 66', prediction=0.0, probability=DenseVector([0.9273, 0.0727]))
# Row(PersonInfo='0 45 1 0 0 0 0 1 0 172 137 92.5 30.35 90 83', prediction=0.0, probability=DenseVector([0.9955, 0.0045]))
# Row(PersonInfo='0 39 3 0 0 0 0 0 0 194 115 70 25.73 70 54', prediction=0.0, probability=DenseVector([0.9988, 0.0012]))
# Row(PersonInfo='1 55 1 0 0 0 0 0 0 255 129 78 26.36 69 79', prediction=0.0, probability=DenseVector([0.9713, 0.0287]))
# Row(PersonInfo='1 54 1 0 0 0 0 0 0 206 141 92 35.85 75 120', prediction=0.0, probability=DenseVector([0.9594, 0.0406]))
# Row(PersonInfo='0 61 2 1 20 0 0 1 0 326 141 75 26.11 60 72', prediction=1.0, probability=DenseVector([0.2355, 0.7645]))
# Row(PersonInfo='0 63 4 0 0 0 0 0 0 232 126 66 22.62 55 79', prediction=0.0, probability=DenseVector([0.8586, 0.1414]))
# Row(PersonInfo='0 58 2 1 3 0 0 0 0 242 123 69 23.38 74 72', prediction=1.0, probability=DenseVector([0.427, 0.573]))
# Row(PersonInfo='1 52 1 1 20 0 0 0 0 262 100 68 18.65 70 74', prediction=0.0, probability=DenseVector([0.912, 0.088]))
# Row(PersonInfo='0 52 3 0 0 0 0 0 0 234 126 85 26.36 72 96', prediction=0.0, probability=DenseVector([0.95, 0.05]))
# Row(PersonInfo='1 62 1 0 0 0 0 0 0 275 111 63 22.68 75 78', prediction=0.0, probability=DenseVector([0.843, 0.157]))
# Row(PersonInfo='0 56 3 0 0 0 0 0 0 248 112.5 60 22.69 75 92', prediction=0.0, probability=DenseVector([0.9984, 0.0016]))
# Row(PersonInfo='1 49 2 1 20 0 0 1 0 273 142 108 23.19 95 72', prediction=1.0, probability=DenseVector([0.4819, 0.5181]))
# Row(PersonInfo='0 41 1 1 43 0 0 1 0 306 199 106 38.75 100 75', prediction=0.0, probability=DenseVector([0.9948, 0.0052]))
# Row(PersonInfo='1 51 4 1 10 0 0 1 0 269 134 92 30.39 85 81', prediction=0.0, probability=DenseVector([0.8564, 0.1436]))
# Row(PersonInfo='0 54 1 0 0 0 0 0 0 218 130 85 20.55 72 85', prediction=0.0, probability=DenseVector([0.8691, 0.1309]))
# Row(PersonInfo='0 48 3 0 0 0 0 0 0 258 109.5 74 26.73 68 75', prediction=0.0, probability=DenseVector([0.9193, 0.0807]))
# Row(PersonInfo='0 45 4 0 0 0 0 0 0 220 108 81 25.68 75 70', prediction=0.0, probability=DenseVector([0.994, 0.006]))
# Row(PersonInfo='1 53 2 1 20 0 0 0 0 211 112.5 70 22.74 63 75', prediction=0.0, probability=DenseVector([0.7423, 0.2577]))
# Row(PersonInfo='0 48 1 0 0 0 0 0 0 193 138.5 87.5 25.1 64 90', prediction=0.0, probability=DenseVector([0.6629, 0.3371]))
# Row(PersonInfo='0 42 4 0 0 0 0 0 0 182 138 91 20.02 90 74', prediction=0.0, probability=DenseVector([0.994, 0.006]))
# Row(PersonInfo='1 40 4 0 0 0 0 1 0 213 145 100.5 27.34 95 117', prediction=0.0, probability=DenseVector([0.9964, 0.0036]))
# Row(PersonInfo='0 45 2 1 20 1 0 1 0 213 150 90 22.35 65 72', prediction=0.0, probability=DenseVector([0.9929, 0.0071]))
# Row(PersonInfo='1 38 1 1 9 0 0 0 0 274 120 80 25.17 80 68', prediction=0.0, probability=DenseVector([1.0, 0.0]))
# Row(PersonInfo='0 46 1 1 20 0 0 0 0 182 117 78 22.15 72 59', prediction=0.0, probability=DenseVector([0.9537, 0.0463]))
# Row(PersonInfo='1 67 1 1 15 0 1 1 0 285 155 90 30.42 70 77', prediction=0.0, probability=DenseVector([0.9487, 0.0513]))
# Row(PersonInfo='1 59 1 0 0 1 0 1 0 294 170 103 31.6 66 70', prediction=0.0, probability=DenseVector([0.9229, 0.0771]))
# Row(PersonInfo='0 53 2 0 0 0 0 1 0 258 186 101 28.9 80 70', prediction=0.0, probability=DenseVector([0.9997, 0.0003]))
# Row(PersonInfo='1 54 1 0 0 0 0 0 0 179 103 73 21.03 60 84', prediction=1.0, probability=DenseVector([0.3786, 0.6214]))
# Row(PersonInfo='0 47 2 0 0 0 0 0 0 187 127.5 90 24.63 110 72', prediction=0.0, probability=DenseVector([0.9971, 0.0029]))
# Row(PersonInfo='1 47 1 0 0 0 0 0 0 219 116 82 24.05 58 87', prediction=0.0, probability=DenseVector([0.984, 0.016]))
# Row(PersonInfo='0 64 4 0 0 0 0 0 0 239 114.5 65.5 19.34 64 75', prediction=1.0, probability=DenseVector([0.4144, 0.5856]))
# Row(PersonInfo='1 61 2 1 15 0 0 0 0 204 120 80 25.71 80 83', prediction=0.0, probability=DenseVector([0.9985, 0.0015]))
# Row(PersonInfo='0 63 1 0 0 0 0 0 0 234 140 93 28.69 60 87', prediction=0.0, probability=DenseVector([0.9963, 0.0037]))
# Row(PersonInfo='0 39 3 1 30 0 0 1 0 235 196 116 29.7 73 87', prediction=0.0, probability=DenseVector([0.9961, 0.0039]))
# Row(PersonInfo='1 53 1 0 0 0 0 0 0 157 123 83 19.94 75 88', prediction=0.0, probability=DenseVector([0.7933, 0.2067]))
# Row(PersonInfo='0 62 3 0 0 0 0 1 0 249 176 89 24.49 75 81', prediction=0.0, probability=DenseVector([0.7533, 0.2467]))
# Row(PersonInfo='1 45 3 1 30 0 0 1 0 270 140 94 30.39 75 80', prediction=0.0, probability=DenseVector([0.949, 0.051]))
# Row(PersonInfo='0 46 3 0 0 0 0 0 0 165 108 81 24.19 80 72', prediction=0.0, probability=DenseVector([0.9825, 0.0175]))
# Row(PersonInfo='1 66 4 1 18 0 0 0 0 235 142 76 26.37 57 93', prediction=0.0, probability=DenseVector([0.8001, 0.1999]))
# Row(PersonInfo='0 62 4 0 0 1 0 1 0 274 167 94 28.18 100 80', prediction=0.0, probability=DenseVector([0.9628, 0.0372]))
# Row(PersonInfo='0 61 1 1 10 0 0 0 0 200 187 95.5 21.57 58 64', prediction=0.0, probability=DenseVector([0.9356, 0.0644]))
# Row(PersonInfo='0 41 1 1 15 0 0 0 0 249 107.5 75 23.69 83 78', prediction=0.0, probability=DenseVector([0.7378, 0.2622]))
# Row(PersonInfo='0 36 3 1 20 0 0 0 0 159 121.5 73 20.41 72 75', prediction=0.0, probability=DenseVector([0.9427, 0.0573]))
# Row(PersonInfo='1 52 2 0 0 0 0 0 0 219 136 76 24.49 52 73', prediction=0.0, probability=DenseVector([0.8216, 0.1784]))
# Row(PersonInfo='0 49 2 0 0 0 0 0 0 170 112 79 21 60 80', prediction=0.0, probability=DenseVector([0.95, 0.05]))
# Row(PersonInfo='0 41 1 0 0 1 0 0 0 179 121 83 23.04 66 90', prediction=0.0, probability=DenseVector([0.9958, 0.0042]))
# Row(PersonInfo='0 50 0 1 15 0 0 1 0 253 132 84.5 27.96 88 73', prediction=1.0, probability=DenseVector([0.0057, 0.9943]))
# Row(PersonInfo='0 49 2 1 0 0 0 1 0 233 158 102 25.31 90 72', prediction=1.0, probability=DenseVector([0.1712, 0.8288]))
# Row(PersonInfo='0 50 1 1 9 0 0 0 0 229 114 68 23.2 90 70', prediction=0.0, probability=DenseVector([0.9974, 0.0026]))
# Row(PersonInfo='0 44 1 0 0 0 0 0 0 197 125.5 82.5 25.13 79 50', prediction=0.0, probability=DenseVector([0.9909, 0.0091]))
# Row(PersonInfo='0 58 2 0 0 0 0 1 0 312 161 100.5 21.51 75 64', prediction=1.0, probability=DenseVector([0.1476, 0.8524]))
# Row(PersonInfo='1 52 1 1 2 0 0 0 0 246 122 81 27.61 90 98', prediction=0.0, probability=DenseVector([0.6476, 0.3524]))
# Row(PersonInfo='1 38 2 1 43 0 0 1 0 265 129 85 31.61 68 68', prediction=0.0, probability=DenseVector([0.9828, 0.0172]))
# Row(PersonInfo='1 57 2 1 1 0 0 0 0 242 102 61 23.5 70 82', prediction=0.0, probability=DenseVector([0.9908, 0.0092]))
# Row(PersonInfo='1 39 1 1 20 0 0 0 0 325 122 82 26.04 58 93', prediction=0.0, probability=DenseVector([0.9869, 0.0131]))
# Row(PersonInfo='0 48 2 0 0 0 0 0 0 271 110 74 21.79 56 67', prediction=0.0, probability=DenseVector([0.9806, 0.0194]))
# Row(PersonInfo='0 39 4 1 15 0 0 0 0 229 113.5 72.5 22.33 84 82', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='1 42 1 1 25 0 0 0 0 231 122 84 27.63 66 72', prediction=0.0, probability=DenseVector([0.9898, 0.0102]))
# Row(PersonInfo='0 51 1 1 3 0 0 0 0 246 111.5 74 25.09 78 78', prediction=0.0, probability=DenseVector([0.9797, 0.0203]))
# Row(PersonInfo='1 56 4 0 0 0 0 0 0 232 126 83 25.67 75 75', prediction=0.0, probability=DenseVector([0.928, 0.072]))
# Row(PersonInfo='0 63 1 0 0 0 0 1 0 320 155 81 31.71 64 80', prediction=0.0, probability=DenseVector([0.6592, 0.3408]))
# Row(PersonInfo='0 53 1 0 0 0 0 0 0 246 115 61 25.96 80 60', prediction=0.0, probability=DenseVector([0.999, 0.001]))
# Row(PersonInfo='0 44 3 1 20 0 0 0 0 240 109 71 23.75 70 83', prediction=1.0, probability=DenseVector([0.3354, 0.6646]))
# Row(PersonInfo='0 47 1 0 0 0 0 1 0 305 128 92.5 27.64 75 62', prediction=0.0, probability=DenseVector([0.9291, 0.0709]))
# Row(PersonInfo='1 56 3 0 0 0 0 0 1 214 115 80 25.09 70 292', prediction=0.0, probability=DenseVector([0.582, 0.418]))
# Row(PersonInfo='1 66 1 0 0 0 0 0 0 270 120 76 19.09 64 98', prediction=0.0, probability=DenseVector([0.8493, 0.1507]))
# Row(PersonInfo='0 34 1 1 20 0 0 0 0 175 117.5 73.5 22.15 65 75', prediction=0.0, probability=DenseVector([0.9868, 0.0132]))
# Row(PersonInfo='0 39 1 0 0 0 0 0 0 164 112 63 22.01 60 85', prediction=0.0, probability=DenseVector([0.9991, 0.0009]))
# Row(PersonInfo='1 54 1 1 35 0 0 0 0 240 146 91 24.41 82 70', prediction=0.0, probability=DenseVector([0.9837, 0.0163]))
# Row(PersonInfo='1 61 1 0 0 0 0 1 0 285 182.5 110 28.88 75 75', prediction=0.0, probability=DenseVector([0.9314, 0.0686]))
# Row(PersonInfo='0 49 1 0 0 0 0 0 0 225 115.5 72.5 21.83 69 75', prediction=0.0, probability=DenseVector([0.9833, 0.0167]))
# Row(PersonInfo='0 66 2 1 9 0 0 0 0 225 110 76 18.23 83 85', prediction=0.0, probability=DenseVector([0.9667, 0.0333]))
# Row(PersonInfo='0 57 4 1 15 0 0 0 0 250 117.5 71 23.84 50 75', prediction=0.0, probability=DenseVector([0.8276, 0.1724]))
# Row(PersonInfo='0 35 1 0 0 0 0 0 0 170 110 69 23.48 75 83', prediction=0.0, probability=DenseVector([0.9956, 0.0044]))
# Row(PersonInfo='1 40 1 0 0 0 0 1 0 265 133.5 81.5 23.78 75 84', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='0 53 2 1 30 0 0 0 0 250 149.5 95 28.02 68 75', prediction=0.0, probability=DenseVector([0.998, 0.002]))
# Row(PersonInfo='0 48 3 1 1 0 0 0 0 234 120 81 23.22 67 83', prediction=0.0, probability=DenseVector([0.9939, 0.0061]))
# Row(PersonInfo='0 55 3 0 0 0 0 0 0 269 130 85 21.05 72 74', prediction=0.0, probability=DenseVector([0.9797, 0.0203]))
# Row(PersonInfo='1 44 1 1 40 0 0 0 0 227 146.5 97 26.92 80 67', prediction=0.0, probability=DenseVector([0.9897, 0.0103]))
# Row(PersonInfo='0 47 1 0 0 1 0 1 0 277 138.5 99 39.64 85 81', prediction=0.0, probability=DenseVector([0.9991, 0.0009]))
# Row(PersonInfo='1 48 1 1 20 0 0 0 0 268 116.5 82 21.34 60 82', prediction=0.0, probability=DenseVector([0.9934, 0.0066]))
# Row(PersonInfo='1 49 3 1 40 0 0 1 0 260 142 54 25.4 67 95', prediction=0.0, probability=DenseVector([0.9875, 0.0125]))
# Row(PersonInfo='0 49 3 0 0 0 0 0 0 286 119 85.5 22.29 60 72', prediction=0.0, probability=DenseVector([0.9945, 0.0055]))
# Row(PersonInfo='0 46 1 0 0 0 0 1 0 239 166.5 107 19.27 110 70', prediction=0.0, probability=DenseVector([0.9155, 0.0845]))
# Row(PersonInfo='1 58 2 0 0 0 0 1 0 241 151 102 26 65 90', prediction=0.0, probability=DenseVector([0.6876, 0.3124]))
# Row(PersonInfo='0 39 3 1 20 0 0 0 0 190 106 72 25.64 75 75', prediction=0.0, probability=DenseVector([0.9971, 0.0029]))
# Row(PersonInfo='0 38 1 0 0 0 0 0 0 293 124 78 23.66 78 76', prediction=0.0, probability=DenseVector([0.9975, 0.0025]))
# Row(PersonInfo='0 39 3 1 12 0 0 0 0 200 111 64 19.24 68 60', prediction=1.0, probability=DenseVector([0.4665, 0.5335]))
# Row(PersonInfo='1 54 1 1 30 0 0 0 0 333 127 74 27.97 90 62', prediction=0.0, probability=DenseVector([0.999, 0.001]))
# Row(PersonInfo='1 56 4 0 0 0 0 0 0 296 123 86 25.59 70 63', prediction=1.0, probability=DenseVector([0.2454, 0.7546]))
# Row(PersonInfo='0 38 3 1 5 0 0 0 0 192 130 80 27.51 75 90', prediction=0.0, probability=DenseVector([0.9964, 0.0036]))
# Row(PersonInfo='0 55 1 1 4 0 0 0 0 308 124 76 27.23 75 68', prediction=0.0, probability=DenseVector([0.9745, 0.0255]))
# Row(PersonInfo='0 47 2 0 0 0 0 1 0 215 202 132 20.49 100 77', prediction=0.0, probability=DenseVector([0.9884, 0.0116]))
# Row(PersonInfo='0 36 1 1 15 0 0 0 0 164 100 64 19.87 85 65', prediction=1.0, probability=DenseVector([0.0309, 0.9691]))
# Row(PersonInfo='0 57 2 0 0 0 0 0 0 333 128 84 25.69 75 75', prediction=0.0, probability=DenseVector([0.9974, 0.0026]))
# Row(PersonInfo='1 57 1 1 9 0 0 1 0 274 173 102 27.26 69 75', prediction=0.0, probability=DenseVector([0.954, 0.046]))
# Row(PersonInfo='0 57 1 0 0 0 0 0 0 207 161 97 36.46 75 67', prediction=0.0, probability=DenseVector([0.873, 0.127]))
# Row(PersonInfo='0 39 2 0 0 1 0 1 0 283 159 105 30.06 80 76', prediction=0.0, probability=DenseVector([0.9739, 0.0261]))
# Row(PersonInfo='0 51 1 1 25 0 0 0 0 327 117 70 18.52 90 76', prediction=1.0, probability=DenseVector([0.0321, 0.9679]))
# Row(PersonInfo='1 39 4 0 0 0 0 1 0 320 123 90 24.44 85 69', prediction=0.0, probability=DenseVector([0.9802, 0.0198]))
# Row(PersonInfo='0 51 2 0 0 0 0 0 0 285 136.5 86.5 24.81 70 83', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='0 60 3 0 0 0 0 1 0 325 182 106 27.61 80 77', prediction=0.0, probability=DenseVector([0.5908, 0.4092]))
# Row(PersonInfo='0 55 3 1 20 0 0 0 0 249 109 66.5 24.79 94 85', prediction=0.0, probability=DenseVector([0.632, 0.368]))
# Row(PersonInfo='0 61 1 1 20 0 0 0 0 229 122 83 25.45 78 61', prediction=0.0, probability=DenseVector([0.9873, 0.0127]))
# Row(PersonInfo='1 43 4 1 40 0 0 0 0 226 103.5 60 26.11 90 67', prediction=1.0, probability=DenseVector([0.4763, 0.5237]))
# Row(PersonInfo='0 65 1 0 0 0 0 1 0 245 171 89 23.07 82 93', prediction=0.0, probability=DenseVector([0.8012, 0.1988]))
# Row(PersonInfo='0 45 3 1 20 0 0 0 0 184 147 88 23.48 66 76', prediction=0.0, probability=DenseVector([0.8728, 0.1272]))
# Row(PersonInfo='0 46 2 0 0 0 0 1 0 264 150 99 26.67 80 102', prediction=0.0, probability=DenseVector([0.985, 0.015]))
# Row(PersonInfo='1 42 2 1 35 0 0 1 0 211 138 90 25.49 69 73', prediction=0.0, probability=DenseVector([0.9896, 0.0104]))
# Row(PersonInfo='0 40 4 1 3 0 0 0 0 188 105 65 21.15 58 70', prediction=0.0, probability=DenseVector([0.985, 0.015]))
# Row(PersonInfo='1 60 1 0 0 0 0 0 0 275 132 82 23.53 75 62', prediction=0.0, probability=DenseVector([0.9346, 0.0654]))
# Row(PersonInfo='0 46 2 1 20 0 0 0 0 291 112 78 23.38 80 89', prediction=1.0, probability=DenseVector([0.4925, 0.5075]))
# Row(PersonInfo='1 56 3 0 0 0 0 0 0 205 129 83.5 28.82 56 64', prediction=1.0, probability=DenseVector([0.1918, 0.8082]))
# Row(PersonInfo='0 49 2 0 0 0 0 0 0 275 155 89 25.01 74 85', prediction=0.0, probability=DenseVector([0.9748, 0.0252]))
# Row(PersonInfo='1 59 3 1 20 0 0 0 0 238 112.5 75.5 26.42 58 67', prediction=0.0, probability=DenseVector([0.6942, 0.3058]))
# Row(PersonInfo='0 37 1 0 0 0 0 0 0 300 112 60 23.67 81 75', prediction=0.0, probability=DenseVector([0.8873, 0.1127]))
# Row(PersonInfo='1 43 1 1 20 0 0 0 0 180 131 92 27.18 65 85', prediction=0.0, probability=DenseVector([0.9376, 0.0624]))
# Row(PersonInfo='0 43 3 1 15 0 0 0 0 233 100 70 22.9 75 78', prediction=0.0, probability=DenseVector([0.968, 0.032]))
# Row(PersonInfo='0 58 1 0 0 0 0 0 0 210 102 60 26.98 71 90', prediction=0.0, probability=DenseVector([0.9544, 0.0456]))
# Row(PersonInfo='0 53 1 1 15 0 0 0 0 225 128 77 23.95 80 78', prediction=0.0, probability=DenseVector([0.9128, 0.0872]))
# Row(PersonInfo='0 56 1 0 0 0 0 0 0 227 140 88 24.59 95 78', prediction=0.0, probability=DenseVector([0.7372, 0.2628]))
# Row(PersonInfo='1 57 1 0 0 0 0 1 0 263 146 94 29.08 63 75', prediction=1.0, probability=DenseVector([0.0997, 0.9003]))
# Row(PersonInfo='0 50 3 0 0 0 0 0 0 229 105 72.5 26.25 90 79', prediction=0.0, probability=DenseVector([0.9836, 0.0164]))
# Row(PersonInfo='0 39 1 0 0 0 0 0 0 214 123 78 38.06 66 62', prediction=0.0, probability=DenseVector([0.9545, 0.0455]))
# Row(PersonInfo='0 58 1 0 0 1 0 1 1 294 195 90 27.73 72 127', prediction=0.0, probability=DenseVector([0.9262, 0.0738]))
# Row(PersonInfo='1 66 3 0 0 0 0 1 0 182 151 88 25.22 85 80', prediction=0.0, probability=DenseVector([0.9728, 0.0272]))
# Row(PersonInfo='0 52 2 0 0 0 0 1 0 216 158 98 24.53 70 86', prediction=0.0, probability=DenseVector([0.9897, 0.0103]))
# Row(PersonInfo='0 60 1 0 0 1 0 1 0 273 176 84 22.17 66 79', prediction=0.0, probability=DenseVector([0.9306, 0.0694]))
# Row(PersonInfo='1 42 3 0 0 0 0 0 0 283 137 91 25.41 75 67', prediction=0.0, probability=DenseVector([0.7875, 0.2125]))
# Row(PersonInfo='0 50 2 1 20 0 0 0 0 235 121 78 23.01 52 78', prediction=0.0, probability=DenseVector([0.9984, 0.0016]))
# Row(PersonInfo='0 56 3 0 0 0 0 0 0 344 119 82 26.82 80 105', prediction=0.0, probability=DenseVector([0.9999, 0.0001]))
# Row(PersonInfo='0 61 1 0 0 0 0 0 0 200 115 60 25.5 76 99', prediction=0.0, probability=DenseVector([0.9989, 0.0011]))
# Row(PersonInfo='0 47 1 1 40 0 0 0 0 221 144 91 35.78 85 66', prediction=0.0, probability=DenseVector([0.9485, 0.0515]))
# Row(PersonInfo='1 54 2 1 30 0 0 0 0 219 113 70 20.41 80 53', prediction=0.0, probability=DenseVector([0.9828, 0.0172]))
# Row(PersonInfo='1 42 2 1 20 0 0 0 0 216 125 86.5 23.25 65 57', prediction=0.0, probability=DenseVector([0.9963, 0.0037]))
# Row(PersonInfo='0 65 1 0 0 0 0 0 0 288 146 94.5 26.54 80 74', prediction=0.0, probability=DenseVector([0.9987, 0.0013]))
# Row(PersonInfo='0 53 1 1 3 0 0 0 0 239 112.5 67 25.63 77 74', prediction=0.0, probability=DenseVector([0.9986, 0.0014]))
# Row(PersonInfo='1 64 2 0 0 0 0 0 0 283 113 77 22.73 75 67', prediction=0.0, probability=DenseVector([0.9887, 0.0113]))
# Row(PersonInfo='0 55 3 0 0 0 0 0 0 238 137.5 87 26.89 67 107', prediction=0.0, probability=DenseVector([0.9981, 0.0019]))
# Row(PersonInfo='0 39 2 1 1 0 0 0 0 225 112 74 27.26 85 85', prediction=0.0, probability=DenseVector([0.9544, 0.0456]))
# Row(PersonInfo='0 52 1 1 20 1 0 1 0 161 180 114 32.52 105 104', prediction=0.0, probability=DenseVector([0.5324, 0.4676]))
# Row(PersonInfo='0 54 3 0 0 0 0 0 0 286 110 74 26.28 65 90', prediction=0.0, probability=DenseVector([0.9943, 0.0057]))
# Row(PersonInfo='1 55 4 0 0 0 0 0 1 245 133 78 29.05 73 115', prediction=0.0, probability=DenseVector([0.9617, 0.0383]))
# Row(PersonInfo='0 47 1 0 0 0 0 0 0 210 113 65 21.33 66 62', prediction=0.0, probability=DenseVector([0.9708, 0.0292]))
# Row(PersonInfo='1 38 2 1 20 0 0 1 0 253 133 92 28.82 80 63', prediction=1.0, probability=DenseVector([0.3349, 0.6651]))
# Row(PersonInfo='0 47 1 0 0 0 0 0 0 228 118 84 18.67 75 90', prediction=0.0, probability=DenseVector([0.9728, 0.0272]))
# Row(PersonInfo='1 51 1 0 0 1 0 0 0 166 115 82.5 26.69 64 67', prediction=0.0, probability=DenseVector([0.9309, 0.0691]))
# Row(PersonInfo='1 37 1 1 20 0 0 0 0 261 111.5 72.5 26.48 73 74', prediction=0.0, probability=DenseVector([0.9932, 0.0068]))
# Row(PersonInfo='1 51 1 1 20 0 0 0 0 256 130 75 28.76 60 83', prediction=0.0, probability=DenseVector([0.8079, 0.1921]))
# Row(PersonInfo='0 42 3 1 20 0 0 0 0 193 129 91.5 27.78 95 74', prediction=0.0, probability=DenseVector([0.7574, 0.2426]))
# Row(PersonInfo='0 58 2 0 0 0 0 1 1 240 150 80 26.45 66 255', prediction=0.0, probability=DenseVector([0.5896, 0.4104]))
# Row(PersonInfo='0 52 4 1 20 0 0 0 0 200 110 70 22.52 75 75', prediction=0.0, probability=DenseVector([0.9834, 0.0166]))
# Row(PersonInfo='0 45 3 0 0 0 0 0 0 237 118 84 22.53 68 78', prediction=0.0, probability=DenseVector([0.9927, 0.0073]))
# Row(PersonInfo='1 38 2 1 20 0 0 0 0 227 108 65.5 25.45 85 110', prediction=0.0, probability=DenseVector([0.997, 0.003]))
# Row(PersonInfo='1 45 3 1 35 0 0 0 0 161 122 82 26.09 65 91', prediction=1.0, probability=DenseVector([0.3295, 0.6705]))
# Row(PersonInfo='1 59 4 0 0 0 0 0 0 210 134 84 25.64 58 77', prediction=0.0, probability=DenseVector([0.9863, 0.0137]))
# Row(PersonInfo='0 62 1 0 0 0 0 1 0 262 175 85 30.91 68 72', prediction=0.0, probability=DenseVector([0.9927, 0.0073]))
# Row(PersonInfo='0 43 3 0 0 0 0 0 0 192 107.5 67.5 21.22 67 75', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='0 49 3 0 0 0 0 0 0 238 97 67 23.17 75 77', prediction=0.0, probability=DenseVector([0.9993, 0.0007]))
# Row(PersonInfo='1 45 3 1 30 0 0 0 0 250 126 89.5 28.68 75 92', prediction=1.0, probability=DenseVector([0.3954, 0.6046]))
# Row(PersonInfo='0 46 2 0 0 0 0 0 0 212 132 82 34.52 80 72', prediction=0.0, probability=DenseVector([0.991, 0.009]))
# Row(PersonInfo='1 44 4 1 35 0 0 1 0 198 143.5 90 27.99 50 75', prediction=1.0, probability=DenseVector([0.2516, 0.7484]))
# Row(PersonInfo='1 63 1 1 20 0 1 1 0 213 163 94 25 76 69', prediction=0.0, probability=DenseVector([0.6833, 0.3167]))
# Row(PersonInfo='1 41 1 1 40 0 0 0 0 224 126 79 22.94 53 68', prediction=0.0, probability=DenseVector([0.9954, 0.0046]))
# Row(PersonInfo='1 42 1 1 20 0 0 0 0 319 116 74 26.62 83 136', prediction=0.0, probability=DenseVector([0.9804, 0.0196]))
# Row(PersonInfo='1 63 0 0 0 0 0 1 0 240 136 94 29.17 64 57', prediction=0.0, probability=DenseVector([0.8536, 0.1464]))
# Row(PersonInfo='0 49 1 0 0 0 0 0 0 193 134 88 25.77 69 76', prediction=0.0, probability=DenseVector([0.9023, 0.0977]))
# Row(PersonInfo='1 43 2 0 0 1 0 1 0 234 173 96 27.99 100 76', prediction=0.0, probability=DenseVector([0.5975, 0.4025]))
# Row(PersonInfo='0 50 2 0 0 1 0 1 0 241 132 85 23.81 55 84', prediction=0.0, probability=DenseVector([0.9966, 0.0034]))
# Row(PersonInfo='0 51 0 1 15 0 0 1 0 240 180 107.5 25.33 68 80', prediction=1.0, probability=DenseVector([0.3252, 0.6748]))
# Row(PersonInfo='1 60 1 0 0 0 0 0 0 240 137 84 29.51 82 88', prediction=0.0, probability=DenseVector([0.8586, 0.1414]))
# Row(PersonInfo='0 59 1 1 20 1 0 0 0 225 110 64 28.1 66 64', prediction=1.0, probability=DenseVector([0.4673, 0.5327]))
# Row(PersonInfo='1 36 1 1 15 0 0 0 0 300 102 66.5 25.68 100 100', prediction=0.0, probability=DenseVector([0.5456, 0.4544]))
# Row(PersonInfo='1 36 4 1 35 0 0 0 0 240 114 76 25.82 66 75', prediction=0.0, probability=DenseVector([0.9996, 0.0004]))
# Row(PersonInfo='0 47 1 1 9 0 0 0 0 261 133 77 27.96 87 105', prediction=1.0, probability=DenseVector([0.0565, 0.9435]))
# Row(PersonInfo='0 42 1 1 9 0 0 1 0 274 135 90 22.19 70 75', prediction=0.0, probability=DenseVector([0.9863, 0.0137]))
# Row(PersonInfo='0 52 2 0 0 0 0 1 0 279 148 99 26.64 86 85', prediction=0.0, probability=DenseVector([0.8616, 0.1384]))
# Row(PersonInfo='0 51 2 0 0 0 0 1 0 351 134 97.5 21.66 100 75', prediction=0.0, probability=DenseVector([0.9636, 0.0364]))
# Row(PersonInfo='0 38 4 0 0 0 0 0 0 150 108 70.5 20.42 72 88', prediction=0.0, probability=DenseVector([0.9993, 0.0007]))
# Row(PersonInfo='1 45 1 1 3 0 0 0 0 280 128 82 29.17 60 62', prediction=0.0, probability=DenseVector([0.9952, 0.0048]))
# Row(PersonInfo='1 42 1 1 20 0 0 0 0 225 110 80 22.51 65 77', prediction=0.0, probability=DenseVector([0.9849, 0.0151]))
# Row(PersonInfo='1 46 2 0 0 0 0 0 0 280 142 91 28.09 85 65', prediction=0.0, probability=DenseVector([0.902, 0.098]))
# Row(PersonInfo='0 62 1 0 0 0 0 1 1 390 184.5 83 18.99 87 47', prediction=0.0, probability=DenseVector([0.9945, 0.0055]))
# Row(PersonInfo='1 36 3 1 15 0 0 0 0 245 122 74.5 24.27 79 85', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='1 52 2 1 15 0 0 0 0 240 94 66.5 22.93 70 88', prediction=0.0, probability=DenseVector([0.905, 0.095]))
# Row(PersonInfo='0 38 4 1 20 0 0 0 0 282 135 80 29.14 75 89', prediction=0.0, probability=DenseVector([0.9992, 0.0008]))
# Row(PersonInfo='1 39 2 0 0 0 0 0 0 262 126 91 31.38 72 84', prediction=0.0, probability=DenseVector([0.969, 0.031]))
# Row(PersonInfo='1 68 1 0 0 0 0 1 1 184 157 97 33.16 110 148', prediction=1.0, probability=DenseVector([0.1805, 0.8195]))
# Row(PersonInfo='0 40 3 1 20 0 0 0 0 237 112.5 77.5 23.58 75 84', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='1 60 1 0 0 0 0 0 0 261 122 74 23.77 70 75', prediction=0.0, probability=DenseVector([0.9755, 0.0245]))
# Row(PersonInfo='0 48 3 1 20 0 0 0 0 253 105 59 19.42 62 83', prediction=0.0, probability=DenseVector([0.9856, 0.0144]))
# Row(PersonInfo='0 52 1 0 0 0 0 0 0 275 112 71 25.68 80 75', prediction=0.0, probability=DenseVector([0.9587, 0.0413]))
# Row(PersonInfo='1 44 1 0 0 0 0 0 0 273 120 80 29.89 76 87', prediction=1.0, probability=DenseVector([0.1114, 0.8886]))
# Row(PersonInfo='0 45 2 0 0 0 0 0 0 229 130 80 21.72 75 77', prediction=0.0, probability=DenseVector([0.9931, 0.0069]))
# Row(PersonInfo='1 57 4 0 0 0 0 0 0 251 114 75 26.35 80 72', prediction=0.0, probability=DenseVector([0.9845, 0.0155]))
# Row(PersonInfo='1 57 3 1 20 0 0 0 0 257 138.5 90 25.14 87 101', prediction=1.0, probability=DenseVector([0.21, 0.79]))
# Row(PersonInfo='0 59 1 0 0 0 0 1 0 220 145 86 25.9 90 77', prediction=0.0, probability=DenseVector([0.9909, 0.0091]))
# Row(PersonInfo='1 43 4 1 30 0 0 1 0 200 152 87 26.77 77 75', prediction=1.0, probability=DenseVector([0.2585, 0.7415]))
# Row(PersonInfo='1 52 1 0 0 0 0 0 0 266 117 78 27.39 70 88', prediction=0.0, probability=DenseVector([0.9214, 0.0786]))
# Row(PersonInfo='0 62 1 0 0 0 0 1 0 308 152 98 35.42 75 76', prediction=1.0, probability=DenseVector([0.0545, 0.9455]))
# Row(PersonInfo='0 48 1 0 0 0 0 0 0 270 134 87 24.91 75 77', prediction=0.0, probability=DenseVector([0.9997, 0.0003]))
# Row(PersonInfo='0 46 1 1 20 0 0 0 0 185 137 90 25.2 82 75', prediction=0.0, probability=DenseVector([0.8971, 0.1029]))
# Row(PersonInfo='1 57 3 0 0 0 0 0 0 213 141 90 30.77 60 77', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))
# Row(PersonInfo='0 67 2 0 0 0 0 0 0 249 128 68 25.81 70 87', prediction=0.0, probability=DenseVector([0.9716, 0.0284]))
# Row(PersonInfo='1 65 1 0 0 0 0 1 1 240 235 100 25 68 297', prediction=0.0, probability=DenseVector([0.8969, 0.1031]))
# Row(PersonInfo='0 39 3 0 0 0 0 0 1 209 104 72 23.96 90 103', prediction=1.0, probability=DenseVector([0.3558, 0.6442]))
# Row(PersonInfo='0 50 4 0 0 0 0 0 0 305 114 80 24.33 55 80', prediction=0.0, probability=DenseVector([0.9888, 0.0112]))
# Row(PersonInfo='0 53 1 1 9 0 0 0 0 309 130 86 22.37 82 80', prediction=0.0, probability=DenseVector([0.9995, 0.0005]))
# Row(PersonInfo='1 67 3 0 0 0 0 0 0 250 120 83 22.36 65 78', prediction=0.0, probability=DenseVector([0.9558, 0.0442]))
# Row(PersonInfo='1 54 3 0 0 0 0 1 0 258 146 98.5 26.05 60 68', prediction=0.0, probability=DenseVector([0.7314, 0.2686]))
# Row(PersonInfo='1 48 3 0 0 0 0 1 0 234 141 98 21.06 53 82', prediction=0.0, probability=DenseVector([0.9746, 0.0254]))
# Row(PersonInfo='0 43 3 0 0 0 0 0 0 263 115 82.5 25.91 105 65', prediction=0.0, probability=DenseVector([0.9919, 0.0081]))
# Row(PersonInfo='0 50 1 0 0 0 0 0 0 273 131 93 27.61 80 94', prediction=0.0, probability=DenseVector([0.6461, 0.3539]))
# Row(PersonInfo='1 46 4 0 0 0 0 1 0 220 136.5 99.5 27.78 80 70', prediction=0.0, probability=DenseVector([0.954, 0.046]))
# Row(PersonInfo='0 48 1 0 0 0 0 0 0 164 159 90 26.73 80 63', prediction=0.0, probability=DenseVector([0.9472, 0.0528]))
# Row(PersonInfo='1 54 1 1 20 0 0 0 0 245 128 74 24.85 72 75', prediction=0.0, probability=DenseVector([0.6955, 0.3045]))
# Row(PersonInfo='0 52 3 1 20 0 0 0 0 215 132 82 25.11 71 75', prediction=0.0, probability=DenseVector([0.7838, 0.2162]))
# Row(PersonInfo='0 45 3 0 0 0 0 0 0 246 134 81 21.99 85 76', prediction=0.0, probability=DenseVector([0.9664, 0.0336]))
# Row(PersonInfo='0 40 2 1 20 0 0 0 0 197 124 76 18.06 90 69', prediction=0.0, probability=DenseVector([0.9971, 0.0029]))
# Row(PersonInfo='1 63 4 1 30 0 0 0 0 260 130.5 82 20.12 65 72', prediction=0.0, probability=DenseVector([0.9924, 0.0076]))
# Row(PersonInfo='1 46 1 1 30 1 0 1 0 253 147 85 30.62 100 75', prediction=0.0, probability=DenseVector([0.8914, 0.1086]))
# Row(PersonInfo='0 40 2 1 20 0 0 0 1 200 114 65 21.19 61 150', prediction=0.0, probability=DenseVector([0.9193, 0.0807]))
# ...
# Row(PersonInfo='0 46 3 1 15 0 0 1 0 274 158 97 22.83 92 78', prediction=0.0, probability=DenseVector([0.9477, 0.0523]))
# Row(PersonInfo='1 45 1 1 20 0 0 0 0 212 118 71 21.03 66 83', prediction=1.0, probability=DenseVector([0.1772, 0.8228]))
# Row(PersonInfo='1 39 2 1 15 0 0 0 0 318 118 75.5 27.52 65 70', prediction=1.0, probability=DenseVector([0.0397, 0.9603]))
# Row(PersonInfo='0 34 0 1 10 0 0 0 0 185 108.5 86 19.68 75 70', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='1 43 2 1 45 0 0 1 0 201 126 82 29.48 76 92', prediction=0.0, probability=DenseVector([0.9826, 0.0174]))
# Row(PersonInfo='1 40 1 1 20 0 0 0 0 290 120 89 27.99 80 66', prediction=0.0, probability=DenseVector([0.6076, 0.3924]))
# Row(PersonInfo='0 40 1 1 5 0 0 0 0 199 97 64.5 23.41 71 70', prediction=0.0, probability=DenseVector([0.945, 0.055]))
# Row(PersonInfo='1 39 2 1 10 0 0 0 0 215 102 64.5 24.5 68 62', prediction=0.0, probability=DenseVector([0.9297, 0.0703]))
# Row(PersonInfo='0 51 2 0 0 0 0 0 0 295 131 87 24.41 85 77', prediction=0.0, probability=DenseVector([0.9988, 0.0012]))
# Row(PersonInfo='0 59 1 0 0 0 0 1 0 254 143.5 92.5 35.11 80 70', prediction=0.0, probability=DenseVector([0.9891, 0.0109]))
# Row(PersonInfo='0 67 4 0 0 0 0 0 0 281 101 59 23.1 63 85', prediction=0.0, probability=DenseVector([0.9738, 0.0262]))
# Row(PersonInfo='0 55 1 0 0 0 0 0 0 204 100.5 62 29.44 82 88', prediction=0.0, probability=DenseVector([0.7007, 0.2993]))
# Row(PersonInfo='0 60 4 0 0 0 0 0 0 247 131 81 22.19 95 94', prediction=0.0, probability=DenseVector([0.8373, 0.1627]))
# Row(PersonInfo='1 61 1 0 0 0 0 0 0 238 119 78 25.36 80 75', prediction=0.0, probability=DenseVector([0.9972, 0.0028]))
# Row(PersonInfo='1 52 3 0 0 0 0 1 0 232 154 92 26.51 90 74', prediction=0.0, probability=DenseVector([0.9731, 0.0269]))
# Row(PersonInfo='1 58 3 0 0 1 1 1 0 241 164 97 32.18 65 54', prediction=0.0, probability=DenseVector([0.9189, 0.0811]))
# Row(PersonInfo='0 48 1 0 0 0 0 1 0 224 152.5 90 29.8 67 85', prediction=0.0, probability=DenseVector([0.902, 0.098]))
# Row(PersonInfo='0 59 1 0 0 0 0 0 0 254 116 71 25.48 75 98', prediction=0.0, probability=DenseVector([0.9933, 0.0067]))
# Row(PersonInfo='1 53 2 0 0 0 0 0 1 234 113 68 24.8 76 108', prediction=0.0, probability=DenseVector([0.9944, 0.0056]))
# Row(PersonInfo='1 43 2 0 0 0 0 0 0 210 127.5 82.5 27.94 78 80', prediction=0.0, probability=DenseVector([0.9977, 0.0023]))
# Row(PersonInfo='1 54 3 1 30 0 0 1 0 267 141.5 91 25.36 92 87', prediction=0.0, probability=DenseVector([0.9939, 0.0061]))
# Row(PersonInfo='0 46 3 1 10 0 0 0 0 205 115 75 19.48 55 78', prediction=0.0, probability=DenseVector([0.9618, 0.0382]))
# Row(PersonInfo='0 53 4 0 0 0 0 1 0 263 173 89 23.03 65 82', prediction=0.0, probability=DenseVector([0.9912, 0.0088]))
# Row(PersonInfo='1 51 1 1 40 0 0 1 0 227 162.5 104 34.97 90 65', prediction=0.0, probability=DenseVector([0.8426, 0.1574]))
# Row(PersonInfo='1 65 1 1 6 0 0 1 0 238 146 86 29.47 75 66', prediction=0.0, probability=DenseVector([0.7329, 0.2671]))
# Row(PersonInfo='0 41 2 1 20 0 0 0 0 235 129 94 23.71 102 81', prediction=0.0, probability=DenseVector([0.9909, 0.0091]))
# Row(PersonInfo='0 53 2 0 0 0 0 1 0 230 170 113 29.55 115 115', prediction=0.0, probability=DenseVector([0.9868, 0.0132]))
# Row(PersonInfo='1 39 2 1 25 0 0 0 0 206 124 78 19.98 69 80', prediction=0.0, probability=DenseVector([0.9178, 0.0822]))
# Row(PersonInfo='1 55 4 0 0 0 0 0 0 232 132.5 87 20.72 72 71', prediction=1.0, probability=DenseVector([0.2745, 0.7255]))
# Row(PersonInfo='1 62 1 0 0 0 0 0 0 252 156.5 93 28.65 88 97', prediction=0.0, probability=DenseVector([0.6523, 0.3477]))
# Row(PersonInfo='0 62 1 0 0 0 0 0 0 266 124 69 22.9 66 82', prediction=0.0, probability=DenseVector([0.9792, 0.0208]))
# Row(PersonInfo='0 53 2 0 0 0 0 1 0 279 167 101 30.85 90 87', prediction=0.0, probability=DenseVector([0.7419, 0.2581]))
# Row(PersonInfo='0 42 3 0 0 0 0 0 0 215 111 72 25.38 77 55', prediction=0.0, probability=DenseVector([0.9996, 0.0004]))
# Row(PersonInfo='0 49 3 1 15 0 0 0 0 267 107 74 27.8 65 75', prediction=0.0, probability=DenseVector([0.9666, 0.0334]))
# Row(PersonInfo='1 57 1 0 0 1 0 1 0 321 192.5 113 25.94 63 90', prediction=1.0, probability=DenseVector([0.3432, 0.6568]))
# Row(PersonInfo='0 62 1 0 0 0 0 0 0 242 137 75 30.51 60 78', prediction=0.0, probability=DenseVector([0.8841, 0.1159]))
# Row(PersonInfo='0 46 1 0 0 0 0 0 0 199 102 56 21.96 80 84', prediction=0.0, probability=DenseVector([0.9945, 0.0055]))
# Row(PersonInfo='0 67 3 1 5 1 0 1 0 245 169 82 26.05 122 122', prediction=0.0, probability=DenseVector([0.7636, 0.2364]))
# Row(PersonInfo='1 38 4 1 15 0 0 0 0 248 110 61 22.17 85 55', prediction=0.0, probability=DenseVector([0.9948, 0.0052]))
# Row(PersonInfo='0 45 1 0 0 0 0 0 0 285 120 80 27.45 84 93', prediction=0.0, probability=DenseVector([0.9926, 0.0074]))
# Row(PersonInfo='0 58 2 0 0 0 0 1 0 345 188 102 28.89 95 70', prediction=0.0, probability=DenseVector([0.9937, 0.0063]))
# Row(PersonInfo='1 65 4 0 0 0 0 0 0 205 106 73 23.14 66 87', prediction=1.0, probability=DenseVector([0.0195, 0.9805]))
# Row(PersonInfo='1 40 2 0 0 0 0 0 0 192 128 81 25.41 75 76', prediction=0.0, probability=DenseVector([0.9583, 0.0417]))
# Row(PersonInfo='0 57 4 0 0 0 0 1 0 236 164 100 25.45 90 67', prediction=0.0, probability=DenseVector([0.9045, 0.0955]))
# Row(PersonInfo='1 38 4 0 0 0 0 0 0 210 116.5 74 21.19 65 89', prediction=0.0, probability=DenseVector([0.9917, 0.0083]))
# Row(PersonInfo='0 63 1 0 0 0 0 1 0 258 166 92 26.91 75 70', prediction=0.0, probability=DenseVector([0.7275, 0.2725]))
# Row(PersonInfo='1 44 1 0 0 0 0 1 0 212 130 94 26.97 80 64', prediction=0.0, probability=DenseVector([0.9477, 0.0523]))
# Row(PersonInfo='1 59 3 1 20 0 0 1 0 206 187 97 26 100 69', prediction=0.0, probability=DenseVector([0.7347, 0.2653]))
# Row(PersonInfo='1 43 4 1 20 0 0 0 0 184 127.5 81 28.31 108 75', prediction=0.0, probability=DenseVector([0.9986, 0.0014]))
# Row(PersonInfo='0 56 2 0 0 0 0 1 0 233 173 98.5 21.88 62 76', prediction=0.0, probability=DenseVector([0.9211, 0.0789]))
# Row(PersonInfo='1 40 1 1 20 0 0 0 0 191 130.5 63 23.92 79 66', prediction=0.0, probability=DenseVector([0.9991, 0.0009]))
# Row(PersonInfo='0 49 3 1 4 0 0 1 0 227 150 91 24.3 88 83', prediction=1.0, probability=DenseVector([0.0375, 0.9625]))
# Row(PersonInfo='1 49 2 0 0 0 0 0 0 239 116 84 31.47 88 76', prediction=0.0, probability=DenseVector([0.9686, 0.0314]))
# Row(PersonInfo='1 51 0 0 0 0 0 0 0 219 125 84 20.12 72 76', prediction=0.0, probability=DenseVector([0.9905, 0.0095]))
# Row(PersonInfo='1 52 1 1 20 0 0 1 0 283 145 79 30.12 72 70', prediction=0.0, probability=DenseVector([0.8789, 0.1211]))
# Row(PersonInfo='0 41 1 0 0 0 0 0 0 179 111 79 25.87 85 82', prediction=0.0, probability=DenseVector([0.9973, 0.0027]))
# Row(PersonInfo='1 40 2 1 20 0 0 0 0 211 117 76 25.74 70 79', prediction=0.0, probability=DenseVector([0.953, 0.047]))
# Row(PersonInfo='0 39 2 1 40 0 0 0 0 200 105 67.5 24.43 90 70', prediction=0.0, probability=DenseVector([0.9991, 0.0009]))
# Row(PersonInfo='0 52 1 0 0 0 0 0 0 292 125 87 31.92 75 67', prediction=0.0, probability=DenseVector([0.798, 0.202]))
# Row(PersonInfo='0 44 3 0 0 0 0 0 0 180 120 80 21.67 60 70', prediction=0.0, probability=DenseVector([0.9967, 0.0033]))
# Row(PersonInfo='0 55 2 0 0 0 0 0 0 273 125 80 23.05 85 67', prediction=0.0, probability=DenseVector([0.9485, 0.0515]))
# Row(PersonInfo='0 61 4 0 0 0 0 1 0 235 207 122.5 31.64 80 72', prediction=1.0, probability=DenseVector([0.2751, 0.7249]))
# Row(PersonInfo='0 54 3 0 0 0 0 0 0 238 136.5 85 24.96 80 71', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='1 51 4 0 0 0 0 0 0 199 113 68 22.46 58 68', prediction=0.0, probability=DenseVector([0.9945, 0.0055]))
# Row(PersonInfo='0 51 3 1 43 0 0 0 0 200 122 76 25.73 80 70', prediction=0.0, probability=DenseVector([0.9847, 0.0153]))
# Row(PersonInfo='0 40 1 0 0 0 0 0 0 190 122 78 28.18 86 87', prediction=0.0, probability=DenseVector([0.9111, 0.0889]))
# Row(PersonInfo='1 41 2 1 15 0 0 0 0 200 118 87 21.28 73 71', prediction=0.0, probability=DenseVector([0.9883, 0.0117]))
# Row(PersonInfo='0 44 1 1 20 0 0 0 0 205 132.5 82.5 30.98 72 66', prediction=1.0, probability=DenseVector([0.2941, 0.7059]))
# Row(PersonInfo='0 46 3 0 0 0 0 0 0 277 122.5 77.5 27.42 63 77', prediction=0.0, probability=DenseVector([1.0, 0.0]))
# Row(PersonInfo='1 44 1 1 25 0 0 0 0 254 123 82 24.56 87 68', prediction=1.0, probability=DenseVector([0.2114, 0.7886]))
# Row(PersonInfo='1 62 2 1 20 0 0 0 0 264 129 85 26.15 73 63', prediction=0.0, probability=DenseVector([0.9309, 0.0691]))
# Row(PersonInfo='1 63 2 1 6 0 0 0 0 217 125 71 25.91 75 74', prediction=1.0, probability=DenseVector([0.495, 0.505]))
# Row(PersonInfo='0 55 1 0 0 0 0 0 0 266 107 70 24.51 72 77', prediction=0.0, probability=DenseVector([0.9923, 0.0077]))
# Row(PersonInfo='1 36 2 0 0 0 0 1 0 153 143 87 28.3 63 82', prediction=0.0, probability=DenseVector([0.9942, 0.0058]))
# Row(PersonInfo='1 60 1 1 1 1 0 1 0 232 173 106 28.63 85 64', prediction=0.0, probability=DenseVector([0.6152, 0.3848]))
# Row(PersonInfo='0 40 2 1 20 0 0 0 0 213 130 80 19.98 96 76', prediction=0.0, probability=DenseVector([0.9982, 0.0018]))
# Row(PersonInfo='0 56 2 0 0 0 0 1 0 199 160 105 25.71 75 83', prediction=0.0, probability=DenseVector([0.9955, 0.0045]))
# Row(PersonInfo='1 46 2 1 20 0 0 0 0 214 110 73 18.1 60 60', prediction=0.0, probability=DenseVector([0.9699, 0.0301]))
# Row(PersonInfo='1 50 2 1 20 0 0 0 0 262 97.5 62.5 21.55 80 84', prediction=1.0, probability=DenseVector([0.0289, 0.9711]))
# Row(PersonInfo='1 39 1 1 20 0 0 0 0 253 104 64 27.48 65 74', prediction=0.0, probability=DenseVector([0.9792, 0.0208]))
# Row(PersonInfo='0 44 1 0 0 0 0 0 0 160 107 69 18.63 125 78', prediction=0.0, probability=DenseVector([0.9969, 0.0031]))
# Row(PersonInfo='1 44 2 0 0 0 0 0 0 254 130 80 28.15 80 74', prediction=1.0, probability=DenseVector([0.307, 0.693]))
# Row(PersonInfo='0 48 2 0 0 0 0 1 0 224 192.5 115 23.03 67 85', prediction=0.0, probability=DenseVector([0.9227, 0.0773]))
# Row(PersonInfo='1 55 2 0 0 0 0 1 0 198 176 109 28.45 60 85', prediction=0.0, probability=DenseVector([0.9958, 0.0042]))
# Row(PersonInfo='0 53 4 0 0 0 0 0 0 232 116 71.5 21.31 73 83', prediction=1.0, probability=DenseVector([0.1967, 0.8033]))
# Row(PersonInfo='1 47 2 1 20 0 0 0 0 119 117 78.5 26.4 75 78', prediction=0.0, probability=DenseVector([0.8516, 0.1484]))
# Row(PersonInfo='1 42 3 1 30 0 0 0 0 240 133.5 97.5 28.94 86 73', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='0 51 3 0 0 0 0 0 0 264 135 83 26.68 60 74', prediction=0.0, probability=DenseVector([0.8086, 0.1914]))
# Row(PersonInfo='1 51 1 1 30 0 0 0 0 241 118 79 20.09 70 56', prediction=1.0, probability=DenseVector([0.0717, 0.9283]))
# Row(PersonInfo='1 62 1 1 7 0 0 0 0 260 104 69 24.02 70 93', prediction=0.0, probability=DenseVector([0.9172, 0.0828]))
# Row(PersonInfo='0 46 2 0 0 0 0 0 0 247 115 71 27.72 82 69', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='0 54 1 0 0 0 0 1 1 326 187 95 29.94 67 235', prediction=0.0, probability=DenseVector([0.9483, 0.0517]))
# Row(PersonInfo='0 58 1 0 0 0 0 1 0 239 121 81 35.19 58 70', prediction=0.0, probability=DenseVector([0.9959, 0.0041]))
# Row(PersonInfo='0 55 1 0 0 0 0 0 0 195 133.5 81.5 23.46 90 70', prediction=0.0, probability=DenseVector([0.9989, 0.0011]))
# Row(PersonInfo='1 47 1 1 20 0 0 1 0 290 143 88 27.4 96 77', prediction=1.0, probability=DenseVector([0.2161, 0.7839]))
# Row(PersonInfo='0 40 2 1 20 0 0 0 0 221 93 62.5 18.84 64 73', prediction=1.0, probability=DenseVector([0.2581, 0.7419]))
# Row(PersonInfo='0 61 2 0 0 0 0 0 0 271 122 67.5 22.02 73 73', prediction=0.0, probability=DenseVector([0.9921, 0.0079]))
# Row(PersonInfo='1 50 2 1 20 0 0 0 0 256 130 84 28.67 70 67', prediction=0.0, probability=DenseVector([0.964, 0.036]))
# Row(PersonInfo='0 51 2 0 0 0 0 1 0 238 123 80 22.19 80 100', prediction=0.0, probability=DenseVector([0.9465, 0.0535]))
# Row(PersonInfo='1 43 4 1 20 0 0 0 0 171 110 74.5 25.09 70 85', prediction=0.0, probability=DenseVector([0.9426, 0.0574]))
# Row(PersonInfo='0 65 4 0 0 0 0 0 0 280 115 73 19.76 65 58', prediction=0.0, probability=DenseVector([0.9875, 0.0125]))
# Row(PersonInfo='1 47 1 0 0 0 0 1 0 283 146.5 97.5 26.25 66 73', prediction=0.0, probability=DenseVector([0.71, 0.29]))
# Row(PersonInfo='1 51 1 1 20 0 0 0 0 195 122 72 21.51 82 64', prediction=0.0, probability=DenseVector([0.9596, 0.0404]))
# Row(PersonInfo='1 40 1 1 40 0 0 0 0 169 127 81 25.82 80 83', prediction=0.0, probability=DenseVector([0.9975, 0.0025]))
# Row(PersonInfo='1 57 1 0 0 0 0 0 0 201 108.5 70.5 22.9 50 84', prediction=0.0, probability=DenseVector([0.9972, 0.0028]))
# Row(PersonInfo='1 38 3 0 0 0 0 1 0 216 124 84 28.12 63 75', prediction=0.0, probability=DenseVector([0.9997, 0.0003]))
# Row(PersonInfo='1 57 1 0 0 0 0 0 0 176 147.5 87.5 24.15 85 100', prediction=0.0, probability=DenseVector([0.8047, 0.1953]))
# Row(PersonInfo='0 39 3 0 0 0 0 0 0 195 97.5 60 20.62 64 68', prediction=0.0, probability=DenseVector([0.9652, 0.0348]))
# Row(PersonInfo='1 46 1 1 20 0 0 0 0 247 134 96 32.47 80 72', prediction=0.0, probability=DenseVector([0.9827, 0.0173]))
# Row(PersonInfo='0 42 1 0 0 0 0 0 0 179 115 78 25.75 80 77', prediction=0.0, probability=DenseVector([0.9978, 0.0022]))
# Row(PersonInfo='0 42 2 1 20 0 0 0 0 235 128 86 24.05 66 70', prediction=0.0, probability=DenseVector([0.9967, 0.0033]))
# Row(PersonInfo='1 67 0 1 25 0 0 1 0 221 144 84 24.92 72 73', prediction=0.0, probability=DenseVector([0.9137, 0.0863]))
# Row(PersonInfo='1 47 4 1 43 0 0 0 0 227 126 84 19.14 68 74', prediction=0.0, probability=DenseVector([0.9648, 0.0352]))
# Row(PersonInfo='0 38 4 0 0 0 0 0 0 227 99 62 27.16 75 90', prediction=0.0, probability=DenseVector([0.9974, 0.0026]))
# Row(PersonInfo='0 45 1 0 0 0 0 0 0 235 106 58 26.79 75 79', prediction=0.0, probability=DenseVector([0.9966, 0.0034]))
# Row(PersonInfo='0 62 1 0 0 1 0 1 0 325 180 108 35.16 75 81', prediction=0.0, probability=DenseVector([0.726, 0.274]))
# Row(PersonInfo='0 38 1 1 20 0 0 0 0 214 101 70 21.83 75 77', prediction=0.0, probability=DenseVector([0.9981, 0.0019]))
# Row(PersonInfo='0 54 2 0 0 0 0 1 0 302 210 127.5 31.98 68 79', prediction=0.0, probability=DenseVector([0.9057, 0.0943]))
# Row(PersonInfo='1 52 1 0 0 0 0 0 0 266 107 75 25.64 82 98', prediction=0.0, probability=DenseVector([0.9596, 0.0404]))
# Row(PersonInfo='0 54 1 0 0 0 0 0 0 207 137.5 89 25.43 63 72', prediction=0.0, probability=DenseVector([0.9943, 0.0057]))
# Row(PersonInfo='1 58 1 0 0 0 0 0 0 200 116.5 71 27.04 70 86', prediction=1.0, probability=DenseVector([0.0591, 0.9409]))
# Row(PersonInfo='0 49 3 1 8 0 0 0 0 215 106 63 19.22 60 66', prediction=0.0, probability=DenseVector([0.9692, 0.0308]))
# Row(PersonInfo='0 42 2 1 10 0 0 1 0 199 143 79 18.68 92 76', prediction=0.0, probability=DenseVector([0.914, 0.086]))
# Row(PersonInfo='1 45 1 1 20 0 0 0 0 241 129 80 27.11 65 65', prediction=1.0, probability=DenseVector([0.4697, 0.5303]))
# Row(PersonInfo='0 40 2 1 9 0 0 0 0 207 124 78 22.9 46 66', prediction=0.0, probability=DenseVector([0.9951, 0.0049]))
# Row(PersonInfo='0 38 2 0 0 0 0 0 0 216 142 72 22.01 63 75', prediction=0.0, probability=DenseVector([0.9998, 0.0002]))
# Row(PersonInfo='0 46 1 0 0 0 0 0 0 213 136 77 31.02 75 73', prediction=0.0, probability=DenseVector([0.9984, 0.0016]))
# Row(PersonInfo='1 42 2 1 40 0 0 0 0 245 105 70 22.41 65 69', prediction=0.0, probability=DenseVector([0.9987, 0.0013]))
# Row(PersonInfo='1 60 1 0 0 0 0 0 0 252 128 82 21.18 75 70', prediction=0.0, probability=DenseVector([0.9962, 0.0038]))
# Row(PersonInfo='1 50 1 0 0 0 0 0 0 260 119 74 21.85 80 72', prediction=0.0, probability=DenseVector([0.8593, 0.1407]))
# Row(PersonInfo='1 47 2 1 3 0 0 0 0 198 120 80 25.23 75 76', prediction=0.0, probability=DenseVector([0.9184, 0.0816]))
# Row(PersonInfo='0 44 1 1 15 0 0 0 0 210 126.5 87 19.16 86 70', prediction=0.0, probability=DenseVector([0.9711, 0.0289]))
# Row(PersonInfo='0 52 2 0 0 0 0 0 0 269 133.5 83 21.47 80 107', prediction=0.0, probability=DenseVector([0.9994, 0.0006]))

# %%
#Tabulate the predicted outcome
prediction.select("prediction").groupBy("prediction").count().show(truncate=False)
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |0.0       |1174 |
# |1.0       |158  |
# +----------+-----+

# %%
#Tabulate the actual outcome
prediction.select("label").groupBy("label").count().show(truncate=False)
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |0.0  |1147 |
# |1.0  |185  |
# +-----+-----+

# %%
# This table shows:
# 1. The number of patients at risk predicted as not at risk
# 2. The number of patients at risk predicted as at risk
# 3. The number of patients not at risk predicted as not at risk
# 4. The number of patients not at risk predicted as at risk

prediction.crosstab('label', 'prediction').show()
# Out:
# +----------------+----+---+
# |label_prediction| 0.0|1.0|
# +----------------+----+---+
# |             1.0| 150| 35|
# |             0.0|1024|123|
# +----------------+----+---+

# %% [markdown]
# <a id="evaluate_model"></a>
# ## Evaluate the Model
#
# We evaluate the model on a training set and on a test set.  The purpose is to measure the model's predictive accuracy, including the accuracy for new data.

# %%
# Evaluate the Logistic Regression model on a training set
# Select (prediction, true label) and compute test error
pred_lr=model.transform(train).select("prediction", "label")
eval_lr=MulticlassClassificationEvaluator (
    labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy_lr=eval_lr.evaluate(pred_lr)
# create RDD
predictionAndLabels_lr=pred_lr.rdd
metrics_lr=MulticlassMetrics(predictionAndLabels_lr)
precision_lr=metrics_lr.precision(1.0)
recall_lr=metrics_lr.recall(1.0)
f1Measure_lr = metrics_lr.fMeasure(1.0, 1.0)
print ("Model evaluation for the training data")
print ("Accuracy = %s" %accuracy_lr)
print ("Error = %s" % (1-accuracy_lr))
print ("Precision = %s" %precision_lr)
print ("Recall = %s" %recall_lr)
print("F1 Measure = %s" % f1Measure_lr)
# Out:
# Model evaluation for the training data
# Accuracy = 0.9683631361760661
# Error = 0.031636863823933936
# Precision = 0.9669211195928753
# Recall = 0.8278867102396514
# F1 Measure = 0.892018779342723

# %%
# Evaluate the Logistic Regression model on a test set
# Select (prediction, true label) and compute test error
pred_lr=model.transform(test).select("prediction", "label")
eval_lr=MulticlassClassificationEvaluator (
    labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy_lr=eval_lr.evaluate(pred_lr)
# create RDD
predictionAndLabels_lr=pred_lr.rdd
metrics_lr=MulticlassMetrics(predictionAndLabels_lr)
precision_lr=metrics_lr.precision(1.0)
recall_lr=metrics_lr.recall(1.0)
f1Measure_lr = metrics_lr.fMeasure(1.0, 1.0)
print ("Model evaluation for the test data")
print ("Accuracy = %s" %accuracy_lr)
print ("Error = %s" % (1-accuracy_lr))
print ("Precision = %s" %precision_lr)
print ("Recall = %s" %recall_lr)
print ("F1 Measure = %s" % f1Measure_lr)
# Out:
# Model evaluation for the test data
# Accuracy = 0.795045045045045
# Error = 0.20495495495495497
# Precision = 0.22151898734177214
# Recall = 0.1891891891891892
# F1 Measure = 0.2040816326530612

# %%
bin_lr=BinaryClassificationMetrics(predictionAndLabels_lr)

# Area under precision-recall curve
print("Area under PR = %s" % bin_lr.areaUnderPR)
# Area under Receiver operating characteristic curve
print("Area under ROC = %s" % bin_lr.areaUnderROC)
# Out:
# Area under PR = 0.18802029877979246
# Area under ROC = 0.5409764603312991

# %% [markdown]
# <a id="ROC_plot"></a>
# ## ROC Curve Plot
# The Binary Logistic Regression method returns the pyspark.ml.classification.BinaryLogisticRegressionTrainingSummary object. We may use the roc method to obtain the coordinates of the points on Receiver operating characteristic (ROC) curve.  The coordinates are stored in a Dataframe with two fields FPR=false positive rate and TPR=true positive rate

# %%
#The firt 20 ROC curve points
model.stages[2].summary.roc.show()
# Out:
# +--------------------+-------------------+
# |                 FPR|                TPR|
# +--------------------+-------------------+
# |                 0.0|                0.0|
# |                 0.0|0.06318082788671024|
# |                 0.0|0.12636165577342048|
# |                 0.0| 0.1895424836601307|
# |                 0.0|0.25272331154684097|
# |                 0.0| 0.3159041394335512|
# |                 0.0| 0.3790849673202614|
# |                 0.0| 0.4422657952069717|
# |                 0.0| 0.5054466230936819|
# |8.166598611678236E-4| 0.5642701525054467|
# |8.166598611678236E-4| 0.6274509803921569|
# |0.001224989791751...| 0.6884531590413944|
# |0.001633319722335...| 0.7494553376906318|
# |0.003266639444671...|  0.803921568627451|
# |0.006533278889342589| 0.8496732026143791|
# |0.011841567986933442| 0.8845315904139434|
# |0.019191506737443853| 0.9084967320261438|
# | 0.02694977541853818| 0.9302832244008714|
# |0.037566353613719884| 0.9368191721132898|
# |0.045732952225398124| 0.9564270152505446|
# +--------------------+-------------------+
# only showing top 20 rows

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ROC=model.stages[2].summary.roc
df=ROC.toPandas()

df.plot(x='FPR', y='TPR', legend=False)
# Out:
# <AxesSubplot:xlabel='FPR'>
